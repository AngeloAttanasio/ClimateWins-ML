# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import time
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from numpy import unique
from numpy import reshape
from keras.models import Sequential
from sklearn.model_selection import cross_val_score
from keras.layers import Conv1D, Conv2D, Dense, Dropout, BatchNormalization, Flatten, MaxPooling1D
from keras.layers.core import Dense, Dropout
from keras.utils import np_utils
from keras.optimizers import Adam, SGD, RMSprop, Adadelta, Adagrad, Adamax, Nadam, Ftrl
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.wrappers.scikit_learn import KerasClassifier
from math import floor
from sklearn.metrics import make_scorer, accuracy_score
from bayes_opt import BayesianOptimization
from sklearn.model_selection import StratifiedKFold
from keras.layers import LeakyReLU
LeakyReLU = LeakyReLU(alpha=0.1)
import warnings
warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)
from sklearn.model_selection import train_test_split

# %%
df_cleaned_path = "/data/notebook_files/df_cleaned.csv"
df_weather_path = "/data/notebook_files/Weather_dataset.csv"

# %%
df_cleaned = pd.read_csv(df_cleaned_path, index_col = False)
df_cleaned
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>BASEL_cloud_cover</th>
#       <th>STOCKHOLM_humidity</th>
#       <th>MUNCHENB_pressure</th>
#       <th>KASSEL_cloud_cover</th>
#       <th>BASEL_humidity</th>
#       <th>BASEL_pressure</th>
#       <th>BASEL_global_radiation</th>
#       <th>BASEL_precipitation</th>
#       <th>BASEL_sunshine</th>
#       <th>BASEL_temp_mean</th>
#       <th>BASEL_temp_min</th>
#       <th>BASEL_temp_max</th>
#       <th>BELGRADE_cloud_cover</th>
#       <th>BELGRADE_humidity</th>
#       <th>BELGRADE_pressure</th>
#       <th>BELGRADE_global_radiation</th>
#       <th>BELGRADE_precipitation</th>
#       <th>BELGRADE_sunshine</th>
#       <th>BELGRADE_temp_mean</th>
#       <th>BELGRADE_temp_min</th>
#       <th>BELGRADE_temp_max</th>
#       <th>BUDAPEST_cloud_cover</th>
#       <th>BUDAPEST_humidity</th>
#       <th>BUDAPEST_pressure</th>
#       <th>BUDAPEST_global_radiation</th>
#       <th>BUDAPEST_precipitation</th>
#       <th>BUDAPEST_sunshine</th>
#       <th>BUDAPEST_temp_mean</th>
#       <th>BUDAPEST_temp_min</th>
#       <th>BUDAPEST_temp_max</th>
#       <th>DEBILT_cloud_cover</th>
#       <th>DEBILT_humidity</th>
#       <th>DEBILT_pressure</th>
#       <th>DEBILT_global_radiation</th>
#       <th>DEBILT_precipitation</th>
#       <th>DEBILT_sunshine</th>
#       <th>DEBILT_temp_mean</th>
#       <th>DEBILT_temp_min</th>
#       <th>DEBILT_temp_max</th>
#       <th>DUSSELDORF_cloud_cover</th>
#       <th>DUSSELDORF_humidity</th>
#       <th>DUSSELDORF_pressure</th>
#       <th>DUSSELDORF_global_radiation</th>
#       <th>DUSSELDORF_precipitation</th>
#       <th>DUSSELDORF_sunshine</th>
#       <th>DUSSELDORF_temp_mean</th>
#       <th>DUSSELDORF_temp_min</th>
#       <th>DUSSELDORF_temp_max</th>
#       <th>HEATHROW_cloud_cover</th>
#       <th>HEATHROW_humidity</th>
#       <th>HEATHROW_pressure</th>
#       <th>HEATHROW_global_radiation</th>
#       <th>HEATHROW_precipitation</th>
#       <th>HEATHROW_sunshine</th>
#       <th>HEATHROW_temp_mean</th>
#       <th>HEATHROW_temp_min</th>
#       <th>HEATHROW_temp_max</th>
#       <th>KASSEL_humidity</th>
#       <th>KASSEL_pressure</th>
#       <th>KASSEL_global_radiation</th>
#       <th>KASSEL_precipitation</th>
#       <th>KASSEL_sunshine</th>
#       <th>KASSEL_temp_mean</th>
#       <th>KASSEL_temp_min</th>
#       <th>KASSEL_temp_max</th>
#       <th>LJUBLJANA_cloud_cover</th>
#       <th>LJUBLJANA_humidity</th>
#       <th>LJUBLJANA_pressure</th>
#       <th>LJUBLJANA_global_radiation</th>
#       <th>LJUBLJANA_precipitation</th>
#       <th>LJUBLJANA_sunshine</th>
#       <th>LJUBLJANA_temp_mean</th>
#       <th>LJUBLJANA_temp_min</th>
#       <th>LJUBLJANA_temp_max</th>
#       <th>MAASTRICHT_cloud_cover</th>
#       <th>MAASTRICHT_humidity</th>
#       <th>MAASTRICHT_pressure</th>
#       <th>MAASTRICHT_global_radiation</th>
#       <th>MAASTRICHT_precipitation</th>
#       <th>MAASTRICHT_sunshine</th>
#       <th>MAASTRICHT_temp_mean</th>
#       <th>MAASTRICHT_temp_min</th>
#       <th>MAASTRICHT_temp_max</th>
#       <th>MADRID_cloud_cover</th>
#       <th>MADRID_humidity</th>
#       <th>MADRID_pressure</th>
#       <th>MADRID_global_radiation</th>
#       <th>MADRID_precipitation</th>
#       <th>MADRID_sunshine</th>
#       <th>MADRID_temp_mean</th>
#       <th>MADRID_temp_min</th>
#       <th>MADRID_temp_max</th>
#       <th>MUNCHENB_cloud_cover</th>
#       <th>MUNCHENB_humidity</th>
#       <th>MUNCHENB_global_radiation</th>
#       <th>MUNCHENB_precipitation</th>
#       <th>MUNCHENB_sunshine</th>
#       <th>MUNCHENB_temp_mean</th>
#       <th>MUNCHENB_temp_min</th>
#       <th>MUNCHENB_temp_max</th>
#       <th>OSLO_cloud_cover</th>
#       <th>OSLO_humidity</th>
#       <th>OSLO_pressure</th>
#       <th>OSLO_global_radiation</th>
#       <th>OSLO_precipitation</th>
#       <th>OSLO_sunshine</th>
#       <th>OSLO_temp_mean</th>
#       <th>OSLO_temp_min</th>
#       <th>OSLO_temp_max</th>
#       <th>SONNBLICK_cloud_cover</th>
#       <th>SONNBLICK_humidity</th>
#       <th>SONNBLICK_pressure</th>
#       <th>SONNBLICK_global_radiation</th>
#       <th>SONNBLICK_precipitation</th>
#       <th>SONNBLICK_sunshine</th>
#       <th>SONNBLICK_temp_mean</th>
#       <th>SONNBLICK_temp_min</th>
#       <th>SONNBLICK_temp_max</th>
#       <th>STOCKHOLM_cloud_cover</th>
#       <th>STOCKHOLM_pressure</th>
#       <th>STOCKHOLM_global_radiation</th>
#       <th>STOCKHOLM_precipitation</th>
#       <th>STOCKHOLM_sunshine</th>
#       <th>STOCKHOLM_temp_mean</th>
#       <th>STOCKHOLM_temp_min</th>
#       <th>STOCKHOLM_temp_max</th>
#       <th>VALENTIA_cloud_cover</th>
#       <th>VALENTIA_humidity</th>
#       <th>VALENTIA_pressure</th>
#       <th>VALENTIA_global_radiation</th>
#       <th>VALENTIA_precipitation</th>
#       <th>VALENTIA_sunshine</th>
#       <th>VALENTIA_temp_mean</th>
#       <th>VALENTIA_temp_min</th>
#       <th>VALENTIA_temp_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>7</td>
#       <td>0.98</td>
#       <td>1.0304</td>
#       <td>8</td>
#       <td>0.85</td>
#       <td>1.0180</td>
#       <td>0.32</td>
#       <td>0.09</td>
#       <td>0.7</td>
#       <td>6.5</td>
#       <td>0.8</td>
#       <td>10.9</td>
#       <td>1</td>
#       <td>0.81</td>
#       <td>1.0195</td>
#       <td>0.88</td>
#       <td>0.00</td>
#       <td>7.0</td>
#       <td>3.7</td>
#       <td>-0.9</td>
#       <td>7.9</td>
#       <td>4</td>
#       <td>0.67</td>
#       <td>1.017</td>
#       <td>0.44</td>
#       <td>0.01</td>
#       <td>2.3</td>
#       <td>2.4</td>
#       <td>-0.4</td>
#       <td>5.1</td>
#       <td>7</td>
#       <td>0.85</td>
#       <td>1.0032</td>
#       <td>0.07</td>
#       <td>0.25</td>
#       <td>0.0</td>
#       <td>9.3</td>
#       <td>7.4</td>
#       <td>11.0</td>
#       <td>8</td>
#       <td>0.83</td>
#       <td>1.0161</td>
#       <td>0.12</td>
#       <td>0.08</td>
#       <td>0.0</td>
#       <td>10.0</td>
#       <td>7.0</td>
#       <td>11.5</td>
#       <td>7</td>
#       <td>0.91</td>
#       <td>1.0010</td>
#       <td>0.13</td>
#       <td>0.22</td>
#       <td>0.0</td>
#       <td>10.6</td>
#       <td>9.4</td>
#       <td>8.3</td>
#       <td>0.82</td>
#       <td>1.0094</td>
#       <td>0.28</td>
#       <td>0.48</td>
#       <td>1.6</td>
#       <td>7.9</td>
#       <td>3.9</td>
#       <td>9.4</td>
#       <td>8</td>
#       <td>1.00</td>
#       <td>1.0173</td>
#       <td>0.20</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>-0.6</td>
#       <td>-1.9</td>
#       <td>0.5</td>
#       <td>7</td>
#       <td>0.83</td>
#       <td>1.0063</td>
#       <td>0.22</td>
#       <td>0.32</td>
#       <td>1.0</td>
#       <td>9.5</td>
#       <td>8.5</td>
#       <td>11.1</td>
#       <td>6</td>
#       <td>0.92</td>
#       <td>1.0260</td>
#       <td>0.53</td>
#       <td>0.00</td>
#       <td>1.4</td>
#       <td>7.6</td>
#       <td>4.4</td>
#       <td>10.8</td>
#       <td>5</td>
#       <td>0.67</td>
#       <td>0.20</td>
#       <td>0.10</td>
#       <td>0.0</td>
#       <td>6.9</td>
#       <td>1.1</td>
#       <td>10.4</td>
#       <td>8</td>
#       <td>0.98</td>
#       <td>0.9978</td>
#       <td>0.04</td>
#       <td>1.14</td>
#       <td>0.0</td>
#       <td>4.9</td>
#       <td>3.8</td>
#       <td>5.9</td>
#       <td>4</td>
#       <td>0.73</td>
#       <td>1.0304</td>
#       <td>0.48</td>
#       <td>0.01</td>
#       <td>2.3</td>
#       <td>-5.9</td>
#       <td>-8.5</td>
#       <td>-3.2</td>
#       <td>5</td>
#       <td>1.0114</td>
#       <td>0.05</td>
#       <td>0.32</td>
#       <td>0.0</td>
#       <td>4.2</td>
#       <td>2.2</td>
#       <td>4.9</td>
#       <td>5</td>
#       <td>0.88</td>
#       <td>1.0003</td>
#       <td>0.45</td>
#       <td>0.34</td>
#       <td>4.7</td>
#       <td>8.5</td>
#       <td>6.0</td>
#       <td>10.9</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>6</td>
#       <td>0.62</td>
#       <td>1.0292</td>
#       <td>6</td>
#       <td>0.84</td>
#       <td>1.0180</td>
#       <td>0.36</td>
#       <td>1.05</td>
#       <td>1.1</td>
#       <td>6.1</td>
#       <td>3.3</td>

# %%
df_weather = pd.read_csv(df_weather_path, index_col = False)
df_weather
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>DATE</th>
#       <th>BASEL_pleasant_weather</th>
#       <th>BELGRADE_pleasant_weather</th>
#       <th>BUDAPEST_pleasant_weather</th>
#       <th>DEBILT_pleasant_weather</th>
#       <th>DUSSELDORF_pleasant_weather</th>
#       <th>HEATHROW_pleasant_weather</th>
#       <th>KASSEL_pleasant_weather</th>
#       <th>LJUBLJANA_pleasant_weather</th>
#       <th>MAASTRICHT_pleasant_weather</th>
#       <th>MADRID_pleasant_weather</th>
#       <th>MUNCHENB_pleasant_weather</th>
#       <th>OSLO_pleasant_weather</th>
#       <th>SONNBLICK_pleasant_weather</th>
#       <th>STOCKHOLM_pleasant_weather</th>
#       <th>VALENTIA_pleasant_weather</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19600101</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>19600102</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>19600103</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>19600104</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>19600105</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>22945</th>
#       <td>20221027</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22946</th>
#       <td>20221028</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22947</th>
#       <td>20221029</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22948</th>
#       <td>20221030</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22949</th>
#       <td>20221031</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>22950 rows × 16 columns</p>
# </div>

# %%
# Drop unnecessary columns
df_weather = df_weather.drop(['DATE'], axis=1)
df_weather
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>BASEL_pleasant_weather</th>
#       <th>BELGRADE_pleasant_weather</th>
#       <th>BUDAPEST_pleasant_weather</th>
#       <th>DEBILT_pleasant_weather</th>
#       <th>DUSSELDORF_pleasant_weather</th>
#       <th>HEATHROW_pleasant_weather</th>
#       <th>KASSEL_pleasant_weather</th>
#       <th>LJUBLJANA_pleasant_weather</th>
#       <th>MAASTRICHT_pleasant_weather</th>
#       <th>MADRID_pleasant_weather</th>
#       <th>MUNCHENB_pleasant_weather</th>
#       <th>OSLO_pleasant_weather</th>
#       <th>SONNBLICK_pleasant_weather</th>
#       <th>STOCKHOLM_pleasant_weather</th>
#       <th>VALENTIA_pleasant_weather</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>22945</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22946</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22947</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22948</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>22949</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>22950 rows × 15 columns</p>
# </div>

# %%
list(df_cleaned.columns)
# Out:
# ['Unnamed: 0',
#  'BASEL_cloud_cover',
#  'STOCKHOLM_humidity',
#  'MUNCHENB_pressure',
#  'KASSEL_cloud_cover',
#  'BASEL_humidity',
#  'BASEL_pressure',
#  'BASEL_global_radiation',
#  'BASEL_precipitation',
#  'BASEL_sunshine',
#  'BASEL_temp_mean',
#  'BASEL_temp_min',
#  'BASEL_temp_max',
#  'BELGRADE_cloud_cover',
#  'BELGRADE_humidity',
#  'BELGRADE_pressure',
#  'BELGRADE_global_radiation',
#  'BELGRADE_precipitation',
#  'BELGRADE_sunshine',
#  'BELGRADE_temp_mean',
#  'BELGRADE_temp_min',
#  'BELGRADE_temp_max',
#  'BUDAPEST_cloud_cover',
#  'BUDAPEST_humidity',
#  'BUDAPEST_pressure',
#  'BUDAPEST_global_radiation',
#  'BUDAPEST_precipitation',
#  'BUDAPEST_sunshine',
#  'BUDAPEST_temp_mean',
#  'BUDAPEST_temp_min',
#  'BUDAPEST_temp_max',
#  'DEBILT_cloud_cover',
#  'DEBILT_humidity',
#  'DEBILT_pressure',
#  'DEBILT_global_radiation',
#  'DEBILT_precipitation',
#  'DEBILT_sunshine',
#  'DEBILT_temp_mean',
#  'DEBILT_temp_min',
#  'DEBILT_temp_max',
#  'DUSSELDORF_cloud_cover',
#  'DUSSELDORF_humidity',
#  'DUSSELDORF_pressure',
#  'DUSSELDORF_global_radiation',
#  'DUSSELDORF_precipitation',
#  'DUSSELDORF_sunshine',
#  'DUSSELDORF_temp_mean',
#  'DUSSELDORF_temp_min',
#  'DUSSELDORF_temp_max',
#  'HEATHROW_cloud_cover',
#  'HEATHROW_humidity',
#  'HEATHROW_pressure',
#  'HEATHROW_global_radiation',
#  'HEATHROW_precipitation',
#  'HEATHROW_sunshine',
#  'HEATHROW_temp_mean',
#  'HEATHROW_temp_min',
#  'HEATHROW_temp_max',
#  'KASSEL_humidity',
#  'KASSEL_pressure',
#  'KASSEL_global_radiation',
#  'KASSEL_precipitation',
#  'KASSEL_sunshine',
#  'KASSEL_temp_mean',
#  'KASSEL_temp_min',
#  'KASSEL_temp_max',
#  'LJUBLJANA_cloud_cover',
#  'LJUBLJANA_humidity',
#  'LJUBLJANA_pressure',
#  'LJUBLJANA_global_radiation',
#  'LJUBLJANA_precipitation',
#  'LJUBLJANA_sunshine',
#  'LJUBLJANA_temp_mean',
#  'LJUBLJANA_temp_min',
#  'LJUBLJANA_temp_max',
#  'MAASTRICHT_cloud_cover',
#  'MAASTRICHT_humidity',
#  'MAASTRICHT_pressure',
#  'MAASTRICHT_global_radiation',
#  'MAASTRICHT_precipitation',
#  'MAASTRICHT_sunshine',
#  'MAASTRICHT_temp_mean',
#  'MAASTRICHT_temp_min',
#  'MAASTRICHT_temp_max',
#  'MADRID_cloud_cover',
#  'MADRID_humidity',
#  'MADRID_pressure',
#  'MADRID_global_radiation',
#  'MADRID_precipitation',
#  'MADRID_sunshine',
#  'MADRID_temp_mean',
#  'MADRID_temp_min',
#  'MADRID_temp_max',
#  'MUNCHENB_cloud_cover',
#  'MUNCHENB_humidity',
#  'MUNCHENB_global_radiation',
#  'MUNCHENB_precipitation',
#  'MUNCHENB_sunshine',
#  'MUNCHENB_temp_mean',
#  'MUNCHENB_temp_min',
#  'MUNCHENB_temp_max',
#  'OSLO_cloud_cover',
#  'OSLO_humidity',
#  'OSLO_pressure',
#  'OSLO_global_radiation',
#  'OSLO_precipitation',
#  'OSLO_sunshine',
#  'OSLO_temp_mean',
#  'OSLO_temp_min',
#  'OSLO_temp_max',
#  'SONNBLICK_cloud_cover',
#  'SONNBLICK_humidity',
#  'SONNBLICK_pressure',
#  'SONNBLICK_global_radiation',
#  'SONNBLICK_precipitation',
#  'SONNBLICK_sunshine',
#  'SONNBLICK_temp_mean',
#  'SONNBLICK_temp_min',
#  'SONNBLICK_temp_max',
#  'STOCKHOLM_cloud_cover',
#  'STOCKHOLM_pressure',
#  'STOCKHOLM_global_radiation',
#  'STOCKHOLM_precipitation',
#  'STOCKHOLM_sunshine',
#  'STOCKHOLM_temp_mean',
#  'STOCKHOLM_temp_min',
#  'STOCKHOLM_temp_max',
#  'VALENTIA_cloud_cover',
#  'VALENTIA_humidity',
#  'VALENTIA_pressure',
#  'VALENTIA_global_radiation',
#  'VALENTIA_precipitation',
#  'VALENTIA_sunshine',
#  'VALENTIA_temp_mean',
#  'VALENTIA_temp_min',
#  'VALENTIA_temp_max']

# %%
# Drop unnecessary columns
df_cleaned = df_cleaned.drop(['Unnamed: 0'], axis=1)

# %%
df_cleaned
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>BASEL_cloud_cover</th>
#       <th>STOCKHOLM_humidity</th>
#       <th>MUNCHENB_pressure</th>
#       <th>KASSEL_cloud_cover</th>
#       <th>BASEL_humidity</th>
#       <th>BASEL_pressure</th>
#       <th>BASEL_global_radiation</th>
#       <th>BASEL_precipitation</th>
#       <th>BASEL_sunshine</th>
#       <th>BASEL_temp_mean</th>
#       <th>BASEL_temp_min</th>
#       <th>BASEL_temp_max</th>
#       <th>BELGRADE_cloud_cover</th>
#       <th>BELGRADE_humidity</th>
#       <th>BELGRADE_pressure</th>
#       <th>BELGRADE_global_radiation</th>
#       <th>BELGRADE_precipitation</th>
#       <th>BELGRADE_sunshine</th>
#       <th>BELGRADE_temp_mean</th>
#       <th>BELGRADE_temp_min</th>
#       <th>BELGRADE_temp_max</th>
#       <th>BUDAPEST_cloud_cover</th>
#       <th>BUDAPEST_humidity</th>
#       <th>BUDAPEST_pressure</th>
#       <th>BUDAPEST_global_radiation</th>
#       <th>BUDAPEST_precipitation</th>
#       <th>BUDAPEST_sunshine</th>
#       <th>BUDAPEST_temp_mean</th>
#       <th>BUDAPEST_temp_min</th>
#       <th>BUDAPEST_temp_max</th>
#       <th>DEBILT_cloud_cover</th>
#       <th>DEBILT_humidity</th>
#       <th>DEBILT_pressure</th>
#       <th>DEBILT_global_radiation</th>
#       <th>DEBILT_precipitation</th>
#       <th>DEBILT_sunshine</th>
#       <th>DEBILT_temp_mean</th>
#       <th>DEBILT_temp_min</th>
#       <th>DEBILT_temp_max</th>
#       <th>DUSSELDORF_cloud_cover</th>
#       <th>DUSSELDORF_humidity</th>
#       <th>DUSSELDORF_pressure</th>
#       <th>DUSSELDORF_global_radiation</th>
#       <th>DUSSELDORF_precipitation</th>
#       <th>DUSSELDORF_sunshine</th>
#       <th>DUSSELDORF_temp_mean</th>
#       <th>DUSSELDORF_temp_min</th>
#       <th>DUSSELDORF_temp_max</th>
#       <th>HEATHROW_cloud_cover</th>
#       <th>HEATHROW_humidity</th>
#       <th>HEATHROW_pressure</th>
#       <th>HEATHROW_global_radiation</th>
#       <th>HEATHROW_precipitation</th>
#       <th>HEATHROW_sunshine</th>
#       <th>HEATHROW_temp_mean</th>
#       <th>HEATHROW_temp_min</th>
#       <th>HEATHROW_temp_max</th>
#       <th>KASSEL_humidity</th>
#       <th>KASSEL_pressure</th>
#       <th>KASSEL_global_radiation</th>
#       <th>KASSEL_precipitation</th>
#       <th>KASSEL_sunshine</th>
#       <th>KASSEL_temp_mean</th>
#       <th>KASSEL_temp_min</th>
#       <th>KASSEL_temp_max</th>
#       <th>LJUBLJANA_cloud_cover</th>
#       <th>LJUBLJANA_humidity</th>
#       <th>LJUBLJANA_pressure</th>
#       <th>LJUBLJANA_global_radiation</th>
#       <th>LJUBLJANA_precipitation</th>
#       <th>LJUBLJANA_sunshine</th>
#       <th>LJUBLJANA_temp_mean</th>
#       <th>LJUBLJANA_temp_min</th>
#       <th>LJUBLJANA_temp_max</th>
#       <th>MAASTRICHT_cloud_cover</th>
#       <th>MAASTRICHT_humidity</th>
#       <th>MAASTRICHT_pressure</th>
#       <th>MAASTRICHT_global_radiation</th>
#       <th>MAASTRICHT_precipitation</th>
#       <th>MAASTRICHT_sunshine</th>
#       <th>MAASTRICHT_temp_mean</th>
#       <th>MAASTRICHT_temp_min</th>
#       <th>MAASTRICHT_temp_max</th>
#       <th>MADRID_cloud_cover</th>
#       <th>MADRID_humidity</th>
#       <th>MADRID_pressure</th>
#       <th>MADRID_global_radiation</th>
#       <th>MADRID_precipitation</th>
#       <th>MADRID_sunshine</th>
#       <th>MADRID_temp_mean</th>
#       <th>MADRID_temp_min</th>
#       <th>MADRID_temp_max</th>
#       <th>MUNCHENB_cloud_cover</th>
#       <th>MUNCHENB_humidity</th>
#       <th>MUNCHENB_global_radiation</th>
#       <th>MUNCHENB_precipitation</th>
#       <th>MUNCHENB_sunshine</th>
#       <th>MUNCHENB_temp_mean</th>
#       <th>MUNCHENB_temp_min</th>
#       <th>MUNCHENB_temp_max</th>
#       <th>OSLO_cloud_cover</th>
#       <th>OSLO_humidity</th>
#       <th>OSLO_pressure</th>
#       <th>OSLO_global_radiation</th>
#       <th>OSLO_precipitation</th>
#       <th>OSLO_sunshine</th>
#       <th>OSLO_temp_mean</th>
#       <th>OSLO_temp_min</th>
#       <th>OSLO_temp_max</th>
#       <th>SONNBLICK_cloud_cover</th>
#       <th>SONNBLICK_humidity</th>
#       <th>SONNBLICK_pressure</th>
#       <th>SONNBLICK_global_radiation</th>
#       <th>SONNBLICK_precipitation</th>
#       <th>SONNBLICK_sunshine</th>
#       <th>SONNBLICK_temp_mean</th>
#       <th>SONNBLICK_temp_min</th>
#       <th>SONNBLICK_temp_max</th>
#       <th>STOCKHOLM_cloud_cover</th>
#       <th>STOCKHOLM_pressure</th>
#       <th>STOCKHOLM_global_radiation</th>
#       <th>STOCKHOLM_precipitation</th>
#       <th>STOCKHOLM_sunshine</th>
#       <th>STOCKHOLM_temp_mean</th>
#       <th>STOCKHOLM_temp_min</th>
#       <th>STOCKHOLM_temp_max</th>
#       <th>VALENTIA_cloud_cover</th>
#       <th>VALENTIA_humidity</th>
#       <th>VALENTIA_pressure</th>
#       <th>VALENTIA_global_radiation</th>
#       <th>VALENTIA_precipitation</th>
#       <th>VALENTIA_sunshine</th>
#       <th>VALENTIA_temp_mean</th>
#       <th>VALENTIA_temp_min</th>
#       <th>VALENTIA_temp_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7</td>
#       <td>0.98</td>
#       <td>1.0304</td>
#       <td>8</td>
#       <td>0.85</td>
#       <td>1.0180</td>
#       <td>0.32</td>
#       <td>0.09</td>
#       <td>0.7</td>
#       <td>6.5</td>
#       <td>0.8</td>
#       <td>10.9</td>
#       <td>1</td>
#       <td>0.81</td>
#       <td>1.0195</td>
#       <td>0.88</td>
#       <td>0.00</td>
#       <td>7.0</td>
#       <td>3.7</td>
#       <td>-0.9</td>
#       <td>7.9</td>
#       <td>4</td>
#       <td>0.67</td>
#       <td>1.017</td>
#       <td>0.44</td>
#       <td>0.01</td>
#       <td>2.3</td>
#       <td>2.4</td>
#       <td>-0.4</td>
#       <td>5.1</td>
#       <td>7</td>
#       <td>0.85</td>
#       <td>1.0032</td>
#       <td>0.07</td>
#       <td>0.25</td>
#       <td>0.0</td>
#       <td>9.3</td>
#       <td>7.4</td>
#       <td>11.0</td>
#       <td>8</td>
#       <td>0.83</td>
#       <td>1.0161</td>
#       <td>0.12</td>
#       <td>0.08</td>
#       <td>0.0</td>
#       <td>10.0</td>
#       <td>7.0</td>
#       <td>11.5</td>
#       <td>7</td>
#       <td>0.91</td>
#       <td>1.0010</td>
#       <td>0.13</td>
#       <td>0.22</td>
#       <td>0.0</td>
#       <td>10.6</td>
#       <td>9.4</td>
#       <td>8.3</td>
#       <td>0.82</td>
#       <td>1.0094</td>
#       <td>0.28</td>
#       <td>0.48</td>
#       <td>1.6</td>
#       <td>7.9</td>
#       <td>3.9</td>
#       <td>9.4</td>
#       <td>8</td>
#       <td>1.00</td>
#       <td>1.0173</td>
#       <td>0.20</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>-0.6</td>
#       <td>-1.9</td>
#       <td>0.5</td>
#       <td>7</td>
#       <td>0.83</td>
#       <td>1.0063</td>
#       <td>0.22</td>
#       <td>0.32</td>
#       <td>1.0</td>
#       <td>9.5</td>
#       <td>8.5</td>
#       <td>11.1</td>
#       <td>6</td>
#       <td>0.92</td>
#       <td>1.0260</td>
#       <td>0.53</td>
#       <td>0.00</td>
#       <td>1.4</td>
#       <td>7.6</td>
#       <td>4.4</td>
#       <td>10.8</td>
#       <td>5</td>
#       <td>0.67</td>
#       <td>0.20</td>
#       <td>0.10</td>
#       <td>0.0</td>
#       <td>6.9</td>
#       <td>1.1</td>
#       <td>10.4</td>
#       <td>8</td>
#       <td>0.98</td>
#       <td>0.9978</td>
#       <td>0.04</td>
#       <td>1.14</td>
#       <td>0.0</td>
#       <td>4.9</td>
#       <td>3.8</td>
#       <td>5.9</td>
#       <td>4</td>
#       <td>0.73</td>
#       <td>1.0304</td>
#       <td>0.48</td>
#       <td>0.01</td>
#       <td>2.3</td>
#       <td>-5.9</td>
#       <td>-8.5</td>
#       <td>-3.2</td>
#       <td>5</td>
#       <td>1.0114</td>
#       <td>0.05</td>
#       <td>0.32</td>
#       <td>0.0</td>
#       <td>4.2</td>
#       <td>2.2</td>
#       <td>4.9</td>
#       <td>5</td>
#       <td>0.88</td>
#       <td>1.0003</td>
#       <td>0.45</td>
#       <td>0.34</td>
#       <td>4.7</td>
#       <td>8.5</td>
#       <td>6.0</td>
#       <td>10.9</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6</td>
#       <td>0.62</td>
#       <td>1.0292</td>
#       <td>6</td>
#       <td>0.84</td>
#       <td>1.0180</td>
#       <td>0.36</td>
#       <td>1.05</td>
#       <td>1.1</td>
#       <td>6.1</td>
#       <td>3.3</td>
#       <td>10.1</td>
#       <td>6</td>
#       <td>0.84</td>

# %%
X = df_cleaned
y = df_weather
X
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>BASEL_cloud_cover</th>
#       <th>STOCKHOLM_humidity</th>
#       <th>MUNCHENB_pressure</th>
#       <th>KASSEL_cloud_cover</th>
#       <th>BASEL_humidity</th>
#       <th>BASEL_pressure</th>
#       <th>BASEL_global_radiation</th>
#       <th>BASEL_precipitation</th>
#       <th>BASEL_sunshine</th>
#       <th>BASEL_temp_mean</th>
#       <th>BASEL_temp_min</th>
#       <th>BASEL_temp_max</th>
#       <th>BELGRADE_cloud_cover</th>
#       <th>BELGRADE_humidity</th>
#       <th>BELGRADE_pressure</th>
#       <th>BELGRADE_global_radiation</th>
#       <th>BELGRADE_precipitation</th>
#       <th>BELGRADE_sunshine</th>
#       <th>BELGRADE_temp_mean</th>
#       <th>BELGRADE_temp_min</th>
#       <th>BELGRADE_temp_max</th>
#       <th>BUDAPEST_cloud_cover</th>
#       <th>BUDAPEST_humidity</th>
#       <th>BUDAPEST_pressure</th>
#       <th>BUDAPEST_global_radiation</th>
#       <th>BUDAPEST_precipitation</th>
#       <th>BUDAPEST_sunshine</th>
#       <th>BUDAPEST_temp_mean</th>
#       <th>BUDAPEST_temp_min</th>
#       <th>BUDAPEST_temp_max</th>
#       <th>DEBILT_cloud_cover</th>
#       <th>DEBILT_humidity</th>
#       <th>DEBILT_pressure</th>
#       <th>DEBILT_global_radiation</th>
#       <th>DEBILT_precipitation</th>
#       <th>DEBILT_sunshine</th>
#       <th>DEBILT_temp_mean</th>
#       <th>DEBILT_temp_min</th>
#       <th>DEBILT_temp_max</th>
#       <th>DUSSELDORF_cloud_cover</th>
#       <th>DUSSELDORF_humidity</th>
#       <th>DUSSELDORF_pressure</th>
#       <th>DUSSELDORF_global_radiation</th>
#       <th>DUSSELDORF_precipitation</th>
#       <th>DUSSELDORF_sunshine</th>
#       <th>DUSSELDORF_temp_mean</th>
#       <th>DUSSELDORF_temp_min</th>
#       <th>DUSSELDORF_temp_max</th>
#       <th>HEATHROW_cloud_cover</th>
#       <th>HEATHROW_humidity</th>
#       <th>HEATHROW_pressure</th>
#       <th>HEATHROW_global_radiation</th>
#       <th>HEATHROW_precipitation</th>
#       <th>HEATHROW_sunshine</th>
#       <th>HEATHROW_temp_mean</th>
#       <th>HEATHROW_temp_min</th>
#       <th>HEATHROW_temp_max</th>
#       <th>KASSEL_humidity</th>
#       <th>KASSEL_pressure</th>
#       <th>KASSEL_global_radiation</th>
#       <th>KASSEL_precipitation</th>
#       <th>KASSEL_sunshine</th>
#       <th>KASSEL_temp_mean</th>
#       <th>KASSEL_temp_min</th>
#       <th>KASSEL_temp_max</th>
#       <th>LJUBLJANA_cloud_cover</th>
#       <th>LJUBLJANA_humidity</th>
#       <th>LJUBLJANA_pressure</th>
#       <th>LJUBLJANA_global_radiation</th>
#       <th>LJUBLJANA_precipitation</th>
#       <th>LJUBLJANA_sunshine</th>
#       <th>LJUBLJANA_temp_mean</th>
#       <th>LJUBLJANA_temp_min</th>
#       <th>LJUBLJANA_temp_max</th>
#       <th>MAASTRICHT_cloud_cover</th>
#       <th>MAASTRICHT_humidity</th>
#       <th>MAASTRICHT_pressure</th>
#       <th>MAASTRICHT_global_radiation</th>
#       <th>MAASTRICHT_precipitation</th>
#       <th>MAASTRICHT_sunshine</th>
#       <th>MAASTRICHT_temp_mean</th>
#       <th>MAASTRICHT_temp_min</th>
#       <th>MAASTRICHT_temp_max</th>
#       <th>MADRID_cloud_cover</th>
#       <th>MADRID_humidity</th>
#       <th>MADRID_pressure</th>
#       <th>MADRID_global_radiation</th>
#       <th>MADRID_precipitation</th>
#       <th>MADRID_sunshine</th>
#       <th>MADRID_temp_mean</th>
#       <th>MADRID_temp_min</th>
#       <th>MADRID_temp_max</th>
#       <th>MUNCHENB_cloud_cover</th>
#       <th>MUNCHENB_humidity</th>
#       <th>MUNCHENB_global_radiation</th>
#       <th>MUNCHENB_precipitation</th>
#       <th>MUNCHENB_sunshine</th>
#       <th>MUNCHENB_temp_mean</th>
#       <th>MUNCHENB_temp_min</th>
#       <th>MUNCHENB_temp_max</th>
#       <th>OSLO_cloud_cover</th>
#       <th>OSLO_humidity</th>
#       <th>OSLO_pressure</th>
#       <th>OSLO_global_radiation</th>
#       <th>OSLO_precipitation</th>
#       <th>OSLO_sunshine</th>
#       <th>OSLO_temp_mean</th>
#       <th>OSLO_temp_min</th>
#       <th>OSLO_temp_max</th>
#       <th>SONNBLICK_cloud_cover</th>
#       <th>SONNBLICK_humidity</th>
#       <th>SONNBLICK_pressure</th>
#       <th>SONNBLICK_global_radiation</th>
#       <th>SONNBLICK_precipitation</th>
#       <th>SONNBLICK_sunshine</th>
#       <th>SONNBLICK_temp_mean</th>
#       <th>SONNBLICK_temp_min</th>
#       <th>SONNBLICK_temp_max</th>
#       <th>STOCKHOLM_cloud_cover</th>
#       <th>STOCKHOLM_pressure</th>
#       <th>STOCKHOLM_global_radiation</th>
#       <th>STOCKHOLM_precipitation</th>
#       <th>STOCKHOLM_sunshine</th>
#       <th>STOCKHOLM_temp_mean</th>
#       <th>STOCKHOLM_temp_min</th>
#       <th>STOCKHOLM_temp_max</th>
#       <th>VALENTIA_cloud_cover</th>
#       <th>VALENTIA_humidity</th>
#       <th>VALENTIA_pressure</th>
#       <th>VALENTIA_global_radiation</th>
#       <th>VALENTIA_precipitation</th>
#       <th>VALENTIA_sunshine</th>
#       <th>VALENTIA_temp_mean</th>
#       <th>VALENTIA_temp_min</th>
#       <th>VALENTIA_temp_max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7</td>
#       <td>0.98</td>
#       <td>1.0304</td>
#       <td>8</td>
#       <td>0.85</td>
#       <td>1.0180</td>
#       <td>0.32</td>
#       <td>0.09</td>
#       <td>0.7</td>
#       <td>6.5</td>
#       <td>0.8</td>
#       <td>10.9</td>
#       <td>1</td>
#       <td>0.81</td>
#       <td>1.0195</td>
#       <td>0.88</td>
#       <td>0.00</td>
#       <td>7.0</td>
#       <td>3.7</td>
#       <td>-0.9</td>
#       <td>7.9</td>
#       <td>4</td>
#       <td>0.67</td>
#       <td>1.017</td>
#       <td>0.44</td>
#       <td>0.01</td>
#       <td>2.3</td>
#       <td>2.4</td>
#       <td>-0.4</td>
#       <td>5.1</td>
#       <td>7</td>
#       <td>0.85</td>
#       <td>1.0032</td>
#       <td>0.07</td>
#       <td>0.25</td>
#       <td>0.0</td>
#       <td>9.3</td>
#       <td>7.4</td>
#       <td>11.0</td>
#       <td>8</td>
#       <td>0.83</td>
#       <td>1.0161</td>
#       <td>0.12</td>
#       <td>0.08</td>
#       <td>0.0</td>
#       <td>10.0</td>
#       <td>7.0</td>
#       <td>11.5</td>
#       <td>7</td>
#       <td>0.91</td>
#       <td>1.0010</td>
#       <td>0.13</td>
#       <td>0.22</td>
#       <td>0.0</td>
#       <td>10.6</td>
#       <td>9.4</td>
#       <td>8.3</td>
#       <td>0.82</td>
#       <td>1.0094</td>
#       <td>0.28</td>
#       <td>0.48</td>
#       <td>1.6</td>
#       <td>7.9</td>
#       <td>3.9</td>
#       <td>9.4</td>
#       <td>8</td>
#       <td>1.00</td>
#       <td>1.0173</td>
#       <td>0.20</td>
#       <td>0.00</td>
#       <td>0.0</td>
#       <td>-0.6</td>
#       <td>-1.9</td>
#       <td>0.5</td>
#       <td>7</td>
#       <td>0.83</td>
#       <td>1.0063</td>
#       <td>0.22</td>
#       <td>0.32</td>
#       <td>1.0</td>
#       <td>9.5</td>
#       <td>8.5</td>
#       <td>11.1</td>
#       <td>6</td>
#       <td>0.92</td>
#       <td>1.0260</td>
#       <td>0.53</td>
#       <td>0.00</td>
#       <td>1.4</td>
#       <td>7.6</td>
#       <td>4.4</td>
#       <td>10.8</td>
#       <td>5</td>
#       <td>0.67</td>
#       <td>0.20</td>
#       <td>0.10</td>
#       <td>0.0</td>
#       <td>6.9</td>
#       <td>1.1</td>
#       <td>10.4</td>
#       <td>8</td>
#       <td>0.98</td>
#       <td>0.9978</td>
#       <td>0.04</td>
#       <td>1.14</td>
#       <td>0.0</td>
#       <td>4.9</td>
#       <td>3.8</td>
#       <td>5.9</td>
#       <td>4</td>
#       <td>0.73</td>
#       <td>1.0304</td>
#       <td>0.48</td>
#       <td>0.01</td>
#       <td>2.3</td>
#       <td>-5.9</td>
#       <td>-8.5</td>
#       <td>-3.2</td>
#       <td>5</td>
#       <td>1.0114</td>
#       <td>0.05</td>
#       <td>0.32</td>
#       <td>0.0</td>
#       <td>4.2</td>
#       <td>2.2</td>
#       <td>4.9</td>
#       <td>5</td>
#       <td>0.88</td>
#       <td>1.0003</td>
#       <td>0.45</td>
#       <td>0.34</td>
#       <td>4.7</td>
#       <td>8.5</td>
#       <td>6.0</td>
#       <td>10.9</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6</td>
#       <td>0.62</td>
#       <td>1.0292</td>
#       <td>6</td>
#       <td>0.84</td>
#       <td>1.0180</td>
#       <td>0.36</td>
#       <td>1.05</td>
#       <td>1.1</td>
#       <td>6.1</td>
#       <td>3.3</td>
#       <td>10.1</td>
#       <td>6</td>
#       <td>0.84</td>

# %%
print(X.shape)
print(y.shape)
# Out:
# (22950, 135)
# (22950, 15)

# %%
X = np.array(X)
y = np.array(y)

# %%
# Reshape
X = X.reshape(-1,15,9)

# %%
X.shape
# Out:
# (22950, 15, 9)

# %%
from sklearn.utils.multiclass import type_of_target
type_of_target(y)
# Out:
# 'multilabel-indicator'

# %%
#Use argmax to get rid of on-hot encoding and supply the numerical value.
y = np.argmax(y, axis=1)
y
# Out:
# <pre>array([0, 0, 0, ..., 0, 0, 0])</pre>

# %%
y.shape
# Out:
# (22950,)

# %%
#Split data into training and testing sets.
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (18360, 15, 9) (18360,)
# (4590, 15, 9) (4590,)

# %%
from sklearn.utils.multiclass import type_of_target
type_of_target(y)
# Out:
# 'multiclass'

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = 15 #_count_classes(Y_train)
# Make scorer accuracy
score_acc = make_scorer(accuracy_score)

# %%
# Create function
def bay_area(neurons, activation, kernel, optimizer, learning_rate, batch_size, epochs,
              layers1, layers2, normalization, dropout, dropout_rate): 
    optimizerL = ['SGD', 'Adam', 'RMSprop', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl','SGD']
    optimizerD= {'Adam':Adam(lr=learning_rate), 'SGD':SGD(lr=learning_rate),
                 'RMSprop':RMSprop(lr=learning_rate), 'Adadelta':Adadelta(lr=learning_rate),
                 'Adagrad':Adagrad(lr=learning_rate), 'Adamax':Adamax(lr=learning_rate),
                 'Nadam':Nadam(lr=learning_rate), 'Ftrl':Ftrl(lr=learning_rate)}
    activationL = ['relu', 'sigmoid', 'softplus', 'softsign', 'tanh', 'selu',
                   'elu', 'exponential', LeakyReLU,'relu']
    
    neurons = round(neurons)
    kernel = round(kernel)
    activation = activationL[round(activation)]
    optimizer = optimizerD[optimizerL[round(optimizer)]]
    batch_size = round(batch_size)
    
    epochs = round(epochs)
    layers1 = round(layers1)
    layers2 = round(layers2)
    
    def cnn_model():
        model = Sequential()
        model.add(Conv1D(neurons, kernel_size=kernel,activation=activation, input_shape=(timesteps, input_dim)))
        #model.add(Conv1D(32, kernel_size=1,activation='relu', input_shape=(timesteps, input_dim)))
        
        if normalization > 0.5:
            model.add(BatchNormalization())
        for i in range(layers1):
            model.add(Dense(neurons, activation=activation)) #(neurons, activation=activation))
        if dropout > 0.5:
            model.add(Dropout(dropout_rate, seed=123))
        for i in range(layers2):
            model.add(Dense(neurons, activation=activation))
        model.add(MaxPooling1D())
        model.add(Flatten())
        model.add(Dense(n_classes, activation='softmax')) #sigmoid softmax
        #model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy']) #categorical_crossentropy
        model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy']) #categorical_crossentropy
        return model
    es = EarlyStopping(monitor='accuracy', mode='max', verbose=2, patience=20)
    nn = KerasClassifier(build_fn=cnn_model, epochs=epochs, batch_size=batch_size, verbose=2)
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=123)
    score = cross_val_score(nn, X_train, y_train, scoring=score_acc, cv=kfold, fit_params={'callbacks':[es]}).mean()
    return score

# %%
start = time.time()
params ={
    'neurons': (10, 50),
    'kernel': (1, 3),
    'activation':(0, 9), #9
    'optimizer':(0,7), #7
    'learning_rate':(0.01, 1),
    'batch_size': (200, 500), #(10, 50), #
    'epochs':(20, 50),
    'layers1':(1,3),
    'layers2':(1,3),
    'normalization':(0,1),
    'dropout':(0,1),
    'dropout_rate':(0,0.3)
}
# Run Bayesian Optimization
nn_opt = BayesianOptimization(bay_area, params, random_state=42)
nn_opt.maximize(init_points=15, n_iter=4) #25
print('Search took %s minutes' % ((time.time() - start)/60))
# Out:
# |   iter    |  target   | activa... | batch_... |  dropout  | dropou... |  epochs   |  kernel   |  layers1  |  layers2  | learni... |  neurons  | normal... | optimizer |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Epoch 1/25
# 31/31 - 2s - loss: 2.7096 - accuracy: 0.6211 - 2s/epoch - 50ms/step
# Epoch 2/25
# 31/31 - 0s - loss: 2.6954 - accuracy: 0.6428 - 376ms/epoch - 12ms/step
# Epoch 3/25
# 31/31 - 0s - loss: 2.6902 - accuracy: 0.6428 - 385ms/epoch - 12ms/step
# Epoch 4/25
# 31/31 - 0s - loss: 2.6858 - accuracy: 0.6428 - 379ms/epoch - 12ms/step
# Epoch 5/25
# 31/31 - 0s - loss: 2.6820 - accuracy: 0.6428 - 377ms/epoch - 12ms/step
# Epoch 6/25
# 31/31 - 0s - loss: 2.6785 - accuracy: 0.6428 - 384ms/epoch - 12ms/step
# Epoch 7/25
# 31/31 - 0s - loss: 2.6752 - accuracy: 0.6428 - 382ms/epoch - 12ms/step
# Epoch 8/25
# 31/31 - 0s - loss: 2.6720 - accuracy: 0.6428 - 382ms/epoch - 12ms/step
# Epoch 9/25
# 31/31 - 0s - loss: 2.6690 - accuracy: 0.6428 - 387ms/epoch - 12ms/step
# Epoch 10/25
# 31/31 - 0s - loss: 2.6660 - accuracy: 0.6428 - 375ms/epoch - 12ms/step
# Epoch 11/25
# 31/31 - 0s - loss: 2.6630 - accuracy: 0.6428 - 375ms/epoch - 12ms/step
# Epoch 12/25
# 31/31 - 0s - loss: 2.6600 - accuracy: 0.6428 - 377ms/epoch - 12ms/step
# Epoch 13/25
# 31/31 - 0s - loss: 2.6568 - accuracy: 0.6428 - 393ms/epoch - 13ms/step
# Epoch 14/25
# 31/31 - 0s - loss: 2.6535 - accuracy: 0.6428 - 391ms/epoch - 13ms/step
# Epoch 15/25
# 31/31 - 0s - loss: 2.6499 - accuracy: 0.6428 - 384ms/epoch - 12ms/step
# Epoch 16/25
# 31/31 - 0s - loss: 2.6461 - accuracy: 0.6428 - 374ms/epoch - 12ms/step
# Epoch 17/25
# 31/31 - 0s - loss: 2.6420 - accuracy: 0.6428 - 374ms/epoch - 12ms/step
# Epoch 18/25
# 31/31 - 0s - loss: 2.6375 - accuracy: 0.6428 - 380ms/epoch - 12ms/step
# Epoch 19/25
# 31/31 - 0s - loss: 2.6325 - accuracy: 0.6428 - 384ms/epoch - 12ms/step
# Epoch 20/25
# 31/31 - 0s - loss: 2.6270 - accuracy: 0.6428 - 386ms/epoch - 12ms/step
# Epoch 21/25
# 31/31 - 0s - loss: 2.6209 - accuracy: 0.6428 - 376ms/epoch - 12ms/step
# Epoch 22/25
# 31/31 - 0s - loss: 2.6142 - accuracy: 0.6428 - 387ms/epoch - 12ms/step
# Epoch 22: early stopping
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/25
# 31/31 - 1s - loss: 2.7016 - accuracy: 0.6237 - 1s/epoch - 42ms/step
# Epoch 2/25
# 31/31 - 0s - loss: 2.6953 - accuracy: 0.6428 - 387ms/epoch - 12ms/step
# Epoch 3/25
# 31/31 - 0s - loss: 2.6902 - accuracy: 0.6428 - 382ms/epoch - 12ms/step
# Epoch 4/25
# 31/31 - 0s - loss: 2.6859 - accuracy: 0.6428 - 385ms/epoch - 12ms/step
# Epoch 5/25
# 31/31 - 0s - loss: 2.6821 - accuracy: 0.6428 - 385ms/epoch - 12ms/step
# Epoch 6/25
# 31/31 - 0s - loss: 2.6786 - accuracy: 0.6428 - 383ms/epoch - 12ms/step
# Epoch 7/25
# 31/31 - 0s - loss: 2.6754 - accuracy: 0.6428 - 380ms/epoch - 12ms/step
# Epoch 8/25
# 31/31 - 0s - loss: 2.6723 - accuracy: 0.6428 - 374ms/epoch - 12ms/step
# Epoch 9/25
# 31/31 - 0s - loss: 2.6694 - accuracy: 0.6428 - 379ms/epoch - 12ms/step
# Epoch 10/25
# 31/31 - 0s - loss: 2.6665 - accuracy: 0.6428 - 379ms/epoch - 12ms/step
# Epoch 11/25
# 31/31 - 0s - loss: 2.6637 - accuracy: 0.6428 - 376ms/epoch - 12ms/step
# Epoch 12/25
# 31/31 - 0s - loss: 2.6608 - accuracy: 0.6428 - 383ms/epoch - 12ms/step
# Epoch 13/25
# 31/31 - 0s - loss: 2.6579 - accuracy: 0.6428 - 383ms/epoch - 12ms/step
# Epoch 14/25
# 31/31 - 0s - loss: 2.6548 - accuracy: 0.6428 - 386ms/epoch - 12ms/step
# Epoch 15/25
# 31/31 - 0s - loss: 2.6516 - accuracy: 0.6428 - 372ms/epoch - 12ms/step
# Epoch 16/25
# 31/31 - 0s - loss: 2.6482 - accuracy: 0.6428 - 382ms/epoch - 12ms/step
# Epoch 17/25
# 31/31 - 0s - loss: 2.6445 - accuracy: 0.6428 - 383ms/epoch - 12ms/step
# Epoch 18/25
# 31/31 - 0s - loss: 2.6404 - accuracy: 0.6428 - 373ms/epoch - 12ms/step
# Epoch 19/25
# 31/31 - 0s - loss: 2.6359 - accuracy: 0.6428 - 377ms/epoch - 12ms/step
# Epoch 20/25
# 31/31 - 0s - loss: 2.6308 - accuracy: 0.6428 - 389ms/epoch - 13ms/step
# Epoch 21/25
# 31/31 - 0s - loss: 2.6252 - accuracy: 0.6428 - 395ms/epoch - 13ms/step
# Epoch 22/25
# 31/31 - 0s - loss: 2.6189 - accuracy: 0.6428 - 406ms/epoch - 13ms/step
# Epoch 22: early stopping
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/25
# 31/31 - 1s - loss: 2.7025 - accuracy: 0.6223 - 1s/epoch - 42ms/step
# Epoch 2/25
# 31/31 - 0s - loss: 2.6953 - accuracy: 0.6428 - 383ms/epoch - 12ms/step
# Epoch 3/25
# 31/31 - 0s - loss: 2.6901 - accuracy: 0.6428 - 382ms/epoch - 12ms/step
# Epoch 4/25
# 31/31 - 0s - loss: 2.6857 - accuracy: 0.6428 - 372ms/epoch - 12ms/step
# Epoch 5/25
# 31/31 - 0s - loss: 2.6819 - accuracy: 0.6428 - 367ms/epoch - 12ms/step
# Epoch 6/25
# 31/31 - 0s - loss: 2.6783 - accuracy: 0.6428 - 370ms/epoch - 12ms/step
# Epoch 7/25
# 31/31 - 0s - loss: 2.6750 - accuracy: 0.6428 - 373ms/epoch - 12ms/step
# Epoch 8/25
# 31/31 - 0s - loss: 2.6719 - accuracy: 0.6428 - 375ms/epoch - 12ms/step
# Epoch 9/25
# 31/31 - 0s - loss: 2.6688 - accuracy: 0.6428 - 377ms/epoch - 12ms/step
# Epoch 10/25
# 31/31 - 0s - loss: 2.6658 - accuracy: 0.6428 - 376ms/epoch - 12ms/step
# Epoch 11/25
# 31/31 - 0s - loss: 2.6628 - accuracy: 0.6428 - 380ms/epoch - 12ms/step
# Epoch 12/25
# 31/31 - 0s - loss: 2.6597 - accuracy: 0.6428 - 388ms/epoch - 13ms/step
# Epoch 13/25
# 31/31 - 0s - loss: 2.6565 - accuracy: 0.6428 - 385ms/epoch - 12ms/step
# Epoch 14/25
# 31/31 - 0s - loss: 2.6532 - accuracy: 0.6428 - 410ms/epoch - 13ms/step
# Epoch 15/25
# 31/31 - 0s - loss: 2.6497 - accuracy: 0.6428 - 377ms/epoch - 12ms/step
# Epoch 16/25
# 31/31 - 0s - loss: 2.6460 - accuracy: 0.6428 - 387ms/epoch - 12ms/step
# Epoch 17/25
# 31/31 - 0s - loss: 2.6419 - accuracy: 0.6428 - 391ms/epoch - 13ms/step
# Epoch 18/25
# 31/31 - 0s - loss: 2.6375 - accuracy: 0.6428 - 388ms/epoch - 13ms/step
# Epoch 19/25
# 31/31 - 0s - loss: 2.6326 - accuracy: 0.6428 - 386ms/epoch - 12ms/step
# Epoch 20/25
# 31/31 - 0s - loss: 2.6272 - accuracy: 0.6428 - 386ms/epoch - 12ms/step
# Epoch 21/25
# 31/31 - 0s - loss: 2.6213 - accuracy: 0.6428 - 386ms/epoch - 12ms/step
# Epoch 22/25
# 31/31 - 0s - loss: 2.6148 - accuracy: 0.6428 - 384ms/epoch - 12ms/step
# Epoch 22: early stopping
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/25
# 31/31 - 1s - loss: 2.7009 - accuracy: 0.6253 - 1s/epoch - 43ms/step
# Epoch 2/25
# 31/31 - 0s - loss: 2.6954 - accuracy: 0.6428 - 401ms/epoch - 13ms/step
# Epoch 3/25
# 31/31 - 0s - loss: 2.6903 - accuracy: 0.6428 - 412ms/epoch - 13ms/step
# Epoch 4/25
# 31/31 - 0s - loss: 2.6860 - accuracy: 0.6428 - 422ms/epoch - 14ms/step
# Epoch 5/25
# 31/31 - 0s - loss: 2.6823 - accuracy: 0.6428 - 405ms/epoch - 13ms/step
# Epoch 6/25
# 31/31 - 0s - loss: 2.6789 - accuracy: 0.6428 - 405ms/epoch - 13ms/step
# Epoch 7/25
# 31/31 - 0s - loss: 2.6757 - accuracy: 0.6428 - 403ms/epoch - 13ms/step
# Epoch 8/25
# 31/31 - 0s - loss: 2.6728 - accuracy: 0.6428 - 407ms/epoch - 13ms/step
# Epoch 9/25
# 31/31 - 0s - loss: 2.6700 - accuracy: 0.6428 - 403ms/epoch - 13ms/step
# Epoch 10/25
# 31/31 - 0s - loss: 2.6673 - accuracy: 0.6428 - 410ms/epoch - 13ms/step
# Epoch 11/25
# 31/31 - 0s - loss: 2.6646 - accuracy: 0.6428 - 401ms/epoch - 13ms/step
# Epoch 12/25
# 31/31 - 0s - loss: 2.6620 - accuracy: 0.6428 - 391ms/epoch - 13ms/step
# Epoch 13/25
# 31/31 - 0s - loss: 2.6594 - accuracy: 0.6428 - 394ms/epoch - 13ms/step
# Epoch 14/25
# 31/31 - 0s - loss: 2.6568 - accuracy: 0.6428 - 391ms/epoch - 13ms/step
# Epoch 15/25
# 31/31 - 0s - loss: 2.6541 - accuracy: 0.6428 - 402ms/epoch - 13ms/step
# Epoch 16/25
# 31/31 - 0s - loss: 2.6512 - accuracy: 0.6428 - 396ms/epoch - 13ms/step
# Epoch 17/25
# 31/31 - 0s - loss: 2.6482 - accuracy: 0.6428 - 391ms/epoch - 13ms/step
# Epoch 18/25
# 31/31 - 0s - loss: 2.6449 - accuracy: 0.6428 - 392ms/epoch - 13ms/step
# Epoch 19/25
# 31/31 - 0s - loss: 2.6412 - accuracy: 0.6428 - 393ms/epoch - 13ms/step
# Epoch 20/25
# 31/31 - 0s - loss: 2.6372 - accuracy: 0.6428 - 395ms/epoch - 13ms/step
# Epoch 21/25
# 31/31 - 0s - loss: 2.6327 - accuracy: 0.6428 - 393ms/epoch - 13ms/step
# Epoch 22/25
# 31/31 - 0s - loss: 2.6277 - accuracy: 0.6428 - 399ms/epoch - 13ms/step
# Epoch 22: early stopping
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/25
# 31/31 - 2s - loss: 2.7027 - accuracy: 0.6215 - 2s/epoch - 49ms/step
# Epoch 2/25
# 31/31 - 0s - loss: 2.6954 - accuracy: 0.6428 - 384ms/epoch - 12ms/step
# Epoch 3/25
# 31/31 - 0s - loss: 2.6902 - accuracy: 0.6428 - 398ms/epoch - 13ms/step
# Epoch 4/25
# 31/31 - 0s - loss: 2.6859 - accuracy: 0.6428 - 391ms/epoch - 13ms/step
# Epoch 5/25
# 31/31 - 0s - loss: 2.6821 - accuracy: 0.6428 - 387ms/epoch - 12ms/step
# Epoch 6/25
# 31/31 - 0s - loss: 2.6786 - accuracy: 0.6428 - 394ms/epoch - 13ms/step
# Epoch 7/25
# 31/31 - 0s - loss: 2.6754 - accuracy: 0.6428 - 385ms/epoch - 12ms/step
# Epoch 8/25
# 31/31 - 0s - loss: 2.6723 - accuracy: 0.6428 - 396ms/epoch - 13ms/step
# Epoch 9/25
# 31/31 - 0s - loss: 2.6694 - accuracy: 0.6428 - 395ms/epoch - 13ms/step
# Epoch 10/25
# 31/31 - 0s - loss: 2.6665 - accuracy: 0.6428 - 377ms/epoch - 12ms/step
# Epoch 11/25
# 31/31 - 0s - loss: 2.6637 - accuracy: 0.6428 - 403ms/epoch - 13ms/step
# Epoch 12/25
# 31/31 - 0s - loss: 2.6609 - accuracy: 0.6428 - 394ms/epoch - 13ms/step
# Epoch 13/25
# 31/31 - 0s - loss: 2.6580 - accuracy: 0.6428 - 418ms/epoch - 13ms/step
# Epoch 14/25
# 31/31 - 0s - loss: 2.6550 - accuracy: 0.6428 - 397ms/epoch - 13ms/step
# Epoch 15/25
# 31/31 - 0s - loss: 2.6519 - accuracy: 0.6428 - 395ms/epoch - 13ms/step
# Epoch 16/25
# 31/31 - 0s - loss: 2.6486 - accuracy: 0.6428 - 389ms/epoch - 13ms/step
# Epoch 17/25
# 31/31 - 0s - loss: 2.6450 - accuracy: 0.6428 - 390ms/epoch - 13ms/step
# Epoch 18/25
# 31/31 - 0s - loss: 2.6411 - accuracy: 0.6428 - 394ms/epoch - 13ms/step
# Epoch 19/25
# 31/31 - 0s - loss: 2.6369 - accuracy: 0.6428 - 396ms/epoch - 13ms/step
# Epoch 20/25
# 31/31 - 0s - loss: 2.6322 - accuracy: 0.6428 - 392ms/epoch - 13ms/step
# Epoch 21/25
# 31/31 - 0s - loss: 2.6270 - accuracy: 0.6428 - 392ms/epoch - 13ms/step
# Epoch 22/25
# 31/31 - 0s - loss: 2.6212 - accuracy: 0.6428 - 395ms/epoch - 13ms/step
# Epoch 22: early stopping
# 115/115 [==============================] - 0s 2ms/step
# | 1         | 0.6428    | 3.371     | 485.2     | 0.732     | 0.1796    | 24.68     | 1.312     | 1.116     | 2.732     | 0.6051    | 38.32     | 0.02058   | 6.789     |
# Epoch 1/29
# 56/56 - 1s - loss: nan - accuracy: 0.6428 - 1s/epoch - 18ms/step
# Epoch 2/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 267ms/epoch - 5ms/step
# Epoch 3/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 249ms/epoch - 4ms/step
# Epoch 4/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 5/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 245ms/epoch - 4ms/step
# Epoch 6/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 7/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 8/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 9/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 10/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 227ms/epoch - 4ms/step
# Epoch 11/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 12/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 229ms/epoch - 4ms/step
# Epoch 13/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 14/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 224ms/epoch - 4ms/step
# Epoch 15/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 229ms/epoch - 4ms/step
# Epoch 16/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 233ms/epoch - 4ms/step
# Epoch 17/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 227ms/epoch - 4ms/step
# Epoch 18/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 237ms/epoch - 4ms/step
# Epoch 19/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 244ms/epoch - 4ms/step
# Epoch 20/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 227ms/epoch - 4ms/step
# Epoch 21/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 21: early stopping
# 115/115 [==============================] - 0s 1ms/step
# Epoch 1/29
# 56/56 - 1s - loss: nan - accuracy: 0.6428 - 1s/epoch - 18ms/step
# Epoch 2/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 262ms/epoch - 5ms/step
# Epoch 3/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 236ms/epoch - 4ms/step
# Epoch 4/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 229ms/epoch - 4ms/step
# Epoch 5/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 230ms/epoch - 4ms/step
# Epoch 6/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 230ms/epoch - 4ms/step
# Epoch 7/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 8/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 9/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 242ms/epoch - 4ms/step
# Epoch 10/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 247ms/epoch - 4ms/step
# Epoch 11/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 242ms/epoch - 4ms/step
# Epoch 12/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 238ms/epoch - 4ms/step
# Epoch 13/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 249ms/epoch - 4ms/step
# Epoch 14/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 223ms/epoch - 4ms/step
# Epoch 15/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 16/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 223ms/epoch - 4ms/step
# Epoch 17/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 18/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 228ms/epoch - 4ms/step
# Epoch 19/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 249ms/epoch - 4ms/step
# Epoch 20/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 257ms/epoch - 5ms/step
# Epoch 21/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 21: early stopping
# 115/115 [==============================] - 0s 1ms/step
# Epoch 1/29
# 56/56 - 1s - loss: nan - accuracy: 0.6428 - 1s/epoch - 18ms/step
# Epoch 2/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 254ms/epoch - 5ms/step
# Epoch 3/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 238ms/epoch - 4ms/step
# Epoch 4/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 250ms/epoch - 4ms/step
# Epoch 5/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 255ms/epoch - 5ms/step
# Epoch 6/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 246ms/epoch - 4ms/step
# Epoch 7/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 238ms/epoch - 4ms/step
# Epoch 8/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 249ms/epoch - 4ms/step
# Epoch 9/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 247ms/epoch - 4ms/step
# Epoch 10/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 11/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 12/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 227ms/epoch - 4ms/step
# Epoch 13/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 231ms/epoch - 4ms/step
# Epoch 14/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 15/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 249ms/epoch - 4ms/step
# Epoch 16/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 17/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 227ms/epoch - 4ms/step
# Epoch 18/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 19/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 20/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 21/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 225ms/epoch - 4ms/step
# Epoch 21: early stopping
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/29
# 56/56 - 1s - loss: nan - accuracy: 0.6428 - 1s/epoch - 18ms/step
# Epoch 2/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 258ms/epoch - 5ms/step
# Epoch 3/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 247ms/epoch - 4ms/step
# Epoch 4/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 247ms/epoch - 4ms/step
# Epoch 5/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 265ms/epoch - 5ms/step
# Epoch 6/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 246ms/epoch - 4ms/step
# Epoch 7/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 257ms/epoch - 5ms/step
# Epoch 8/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 272ms/epoch - 5ms/step
# Epoch 9/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 238ms/epoch - 4ms/step
# Epoch 10/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 226ms/epoch - 4ms/step
# Epoch 11/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 238ms/epoch - 4ms/step
# Epoch 12/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 227ms/epoch - 4ms/step
# Epoch 13/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 254ms/epoch - 5ms/step
# Epoch 14/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 266ms/epoch - 5ms/step
# Epoch 15/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 247ms/epoch - 4ms/step
# Epoch 16/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 241ms/epoch - 4ms/step
# Epoch 17/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 256ms/epoch - 5ms/step
# Epoch 18/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 233ms/epoch - 4ms/step
# Epoch 19/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 255ms/epoch - 5ms/step
# Epoch 20/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 269ms/epoch - 5ms/step
# Epoch 21/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 272ms/epoch - 5ms/step
# Epoch 21: early stopping
# 115/115 [==============================] - 0s 1ms/step
# Epoch 1/29
# 56/56 - 1s - loss: nan - accuracy: 0.6428 - 1s/epoch - 19ms/step
# Epoch 2/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 302ms/epoch - 5ms/step
# Epoch 3/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 242ms/epoch - 4ms/step
# Epoch 4/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 260ms/epoch - 5ms/step
# Epoch 5/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 266ms/epoch - 5ms/step
# Epoch 6/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 236ms/epoch - 4ms/step
# Epoch 7/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 251ms/epoch - 4ms/step
# Epoch 8/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 242ms/epoch - 4ms/step
# Epoch 9/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 233ms/epoch - 4ms/step
# Epoch 10/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 238ms/epoch - 4ms/step
# Epoch 11/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 230ms/epoch - 4ms/step
# Epoch 12/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 237ms/epoch - 4ms/step
# Epoch 13/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 248ms/epoch - 4ms/step
# Epoch 14/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 242ms/epoch - 4ms/step
# Epoch 15/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 239ms/epoch - 4ms/step
# Epoch 16/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 243ms/epoch - 4ms/step
# Epoch 17/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 238ms/epoch - 4ms/step
# Epoch 18/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 254ms/epoch - 5ms/step
# Epoch 19/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 241ms/epoch - 4ms/step
# Epoch 20/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 229ms/epoch - 4ms/step
# Epoch 21/29
# 56/56 - 0s - loss: nan - accuracy: 0.6428 - 223ms/epoch - 4ms/step
# Epoch 21: early stopping
# 115/115 [==============================] - 0s 2ms/step
# | 2         | 0.6428    | 7.492     | 263.7     | 0.1818    | 0.05502   | 29.13     | 2.05      | 1.864     | 1.582     | 0.6157    | 15.58     | 0.2921    | 2.565     |
# Epoch 1/38
# 34/34 - 2s - loss: 5.9955 - accuracy: 0.4682 - 2s/epoch - 68ms/step
# Epoch 2/38
# 34/34 - 1s - loss: 8.9863 - accuracy: 0.4796 - 510ms/epoch - 15ms/step
# Epoch 3/38
# 34/34 - 0s - loss: 5.5089 - accuracy: 0.5503 - 427ms/epoch - 13ms/step
# Epoch 4/38
# 34/34 - 1s - loss: 8.6213 - accuracy: 0.5455 - 626ms/epoch - 18ms/step
# Epoch 5/38
# 34/34 - 0s - loss: 7.1123 - accuracy: 0.5414 - 429ms/epoch - 13ms/step
# Epoch 6/38
# 34/34 - 0s - loss: 6.1000 - accuracy: 0.5539 - 423ms/epoch - 12ms/step
# Epoch 7/38
# 34/34 - 0s - loss: 5.6837 - accuracy: 0.5598 - 435ms/epoch - 13ms/step
# Epoch 8/38
# 34/34 - 0s - loss: 4.8486 - accuracy: 0.5600 - 427ms/epoch - 13ms/step
# Epoch 9/38
# 34/34 - 0s - loss: 8.4467 - accuracy: 0.5190 - 427ms/epoch - 13ms/step
# Epoch 10/38
# 34/34 - 0s - loss: 6.6369 - accuracy: 0.5645 - 420ms/epoch - 12ms/step
# Epoch 11/38
# 34/34 - 0s - loss: 7.3998 - accuracy: 0.5581 - 432ms/epoch - 13ms/step
# Epoch 12/38
# 34/34 - 0s - loss: 5.6759 - accuracy: 0.5638 - 420ms/epoch - 12ms/step
# Epoch 13/38
# 34/34 - 0s - loss: 3.8319 - accuracy: 0.5846 - 419ms/epoch - 12ms/step
# Epoch 14/38
# 34/34 - 0s - loss: 6.1300 - accuracy: 0.5640 - 419ms/epoch - 12ms/step
# Epoch 15/38
# 34/34 - 0s - loss: 7.3791 - accuracy: 0.5594 - 413ms/epoch - 12ms/step
# Epoch 16/38
# 34/34 - 0s - loss: 7.1008 - accuracy: 0.5709 - 424ms/epoch - 12ms/step
# Epoch 17/38
# 34/34 - 0s - loss: 5.3670 - accuracy: 0.5796 - 418ms/epoch - 12ms/step
# Epoch 18/38
# 34/34 - 0s - loss: 9.6622 - accuracy: 0.5286 - 419ms/epoch - 12ms/step
# Epoch 19/38
# 34/34 - 0s - loss: 11.0679 - accuracy: 0.5605 - 423ms/epoch - 12ms/step
# Epoch 20/38
# 34/34 - 0s - loss: 7.3820 - accuracy: 0.5590 - 434ms/epoch - 13ms/step
# Epoch 21/38
# 34/34 - 0s - loss: 8.5732 - accuracy: 0.5433 - 433ms/epoch - 13ms/step
# Epoch 22/38
# 34/34 - 0s - loss: 6.5416 - accuracy: 0.5407 - 425ms/epoch - 12ms/step
# Epoch 23/38
# 34/34 - 0s - loss: 9.6331 - accuracy: 0.5219 - 428ms/epoch - 13ms/step
# Epoch 24/38
# 34/34 - 0s - loss: 7.2644 - accuracy: 0.5628 - 427ms/epoch - 13ms/step
# Epoch 25/38
# 34/34 - 0s - loss: 9.4907 - accuracy: 0.5559 - 433ms/epoch - 13ms/step
# Epoch 26/38
# 34/34 - 0s - loss: 8.0238 - accuracy: 0.5562 - 422ms/epoch - 12ms/step
# Epoch 27/38
# 34/34 - 0s - loss: 9.4477 - accuracy: 0.5370 - 422ms/epoch - 12ms/step
# Epoch 28/38
# 34/34 - 0s - loss: 10.7151 - accuracy: 0.5421 - 416ms/epoch - 12ms/step
# Epoch 29/38
# 34/34 - 0s - loss: 7.9674 - accuracy: 0.5373 - 434ms/epoch - 13ms/step
# Epoch 30/38
# 34/34 - 0s - loss: 7.6447 - accuracy: 0.5248 - 471ms/epoch - 14ms/step
# Epoch 31/38
# 34/34 - 0s - loss: 5.7992 - accuracy: 0.5615 - 434ms/epoch - 13ms/step
# Epoch 32/38
# 34/34 - 0s - loss: 7.9069 - accuracy: 0.5402 - 437ms/epoch - 13ms/step
# Epoch 33/38
# 34/34 - 0s - loss: 9.3880 - accuracy: 0.5502 - 411ms/epoch - 12ms/step
# Epoch 33: early stopping
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/38
# 34/34 - 2s - loss: 61.7754 - accuracy: 0.4520 - 2s/epoch - 71ms/step
# Epoch 2/38
# 34/34 - 0s - loss: 33.8002 - accuracy: 0.5195 - 447ms/epoch - 13ms/step
# Epoch 3/38
# 34/34 - 0s - loss: 33.0058 - accuracy: 0.4965 - 426ms/epoch - 13ms/step
# Epoch 4/38
# 34/34 - 0s - loss: 27.0784 - accuracy: 0.5213 - 426ms/epoch - 13ms/step
# Epoch 5/38
# 34/34 - 0s - loss: 26.7105 - accuracy: 0.5186 - 427ms/epoch - 13ms/step
# Epoch 6/38
# 34/34 - 0s - loss: 22.0430 - accuracy: 0.5209 - 430ms/epoch - 13ms/step
# Epoch 7/38
# 34/34 - 0s - loss: 18.8759 - accuracy: 0.5317 - 422ms/epoch - 12ms/step
# Epoch 8/38
# 34/34 - 0s - loss: 18.7527 - accuracy: 0.5253 - 427ms/epoch - 13ms/step
# Epoch 9/38
# 34/34 - 0s - loss: 16.1613 - accuracy: 0.5460 - 441ms/epoch - 13ms/step
# Epoch 10/38
# 34/34 - 0s - loss: 11.1738 - accuracy: 0.5485 - 425ms/epoch - 13ms/step
# Epoch 11/38
# 34/34 - 0s - loss: 18.6101 - accuracy: 0.5118 - 459ms/epoch - 14ms/step
# Epoch 12/38
# 34/34 - 0s - loss: 17.9282 - accuracy: 0.5018 - 444ms/epoch - 13ms/step
# Epoch 13/38
# 34/34 - 0s - loss: 18.6828 - accuracy: 0.5140 - 425ms/epoch - 12ms/step
# Epoch 14/38
# 34/34 - 0s - loss: 17.6441 - accuracy: 0.5322 - 421ms/epoch - 12ms/step
# Epoch 15/38
# 34/34 - 0s - loss: 14.0443 - accuracy: 0.5157 - 460ms/epoch - 14ms/step
# Epoch 16/38
# 34/34 - 0s - loss: 14.1820 - accuracy: 0.5172 - 420ms/epoch - 12ms/step
# Epoch 17/38
# 34/34 - 0s - loss: 16.1139 - accuracy: 0.4927 - 419ms/epoch - 12ms/step
# Epoch 18/38
# 34/34 - 0s - loss: 15.3048 - accuracy: 0.5174 - 437ms/epoch - 13ms/step
# Epoch 19/38
# 34/34 - 0s - loss: 20.4127 - accuracy: 0.4705 - 422ms/epoch - 12ms/step
# Epoch 20/38
# 34/34 - 0s - loss: 17.2241 - accuracy: 0.5126 - 462ms/epoch - 14ms/step
# Epoch 21/38
# 34/34 - 0s - loss: 14.1699 - accuracy: 0.5106 - 418ms/epoch - 12ms/step
# Epoch 22/38
# 34/34 - 0s - loss: 11.1487 - accuracy: 0.5227 - 420ms/epoch - 12ms/step
# Epoch 23/38
# 34/34 - 0s - loss: 11.9151 - accuracy: 0.5116 - 435ms/epoch - 13ms/step
# Epoch 24/38
# 34/34 - 0s - loss: 12.5403 - accuracy: 0.5275 - 417ms/epoch - 12ms/step
# Epoch 25/38
# 34/34 - 0s - loss: 9.3155 - accuracy: 0.5678 - 424ms/epoch - 12ms/step
# Epoch 26/38
# 34/34 - 0s - loss: 7.9840 - accuracy: 0.5576 - 420ms/epoch - 12ms/step
# Epoch 27/38
# 34/34 - 0s - loss: 10.0037 - accuracy: 0.5167 - 424ms/epoch - 12ms/step
# Epoch 28/38
# 34/34 - 0s - loss: 10.7158 - accuracy: 0.5385 - 420ms/epoch - 12ms/step
# Epoch 29/38
# 34/34 - 0s - loss: 9.3866 - accuracy: 0.5433 - 423ms/epoch - 12ms/step
# Epoch 30/38
# 34/34 - 0s - loss: 8.5719 - accuracy: 0.5354 - 419ms/epoch - 12ms/step
# Epoch 31/38
# 34/34 - 0s - loss: 8.3639 - accuracy: 0.5541 - 427ms/epoch - 13ms/step
# Epoch 32/38
# 34/34 - 0s - loss: 14.3630 - accuracy: 0.4908 - 424ms/epoch - 12ms/step
# Epoch 33/38
# 34/34 - 0s - loss: 12.1465 - accuracy: 0.5319 - 422ms/epoch - 12ms/step
# Epoch 34/38
# 34/34 - 0s - loss: 9.7995 - accuracy: 0.5266 - 431ms/epoch - 13ms/step
# Epoch 35/38
# 34/34 - 0s - loss: 10.5637 - accuracy: 0.5285 - 422ms/epoch - 12ms/step
# Epoch 36/38
# 34/34 - 0s - loss: 11.6085 - accuracy: 0.5221 - 422ms/epoch - 12ms/step
# Epoch 37/38
# 34/34 - 0s - loss: 12.3749 - accuracy: 0.5325 - 424ms/epoch - 12ms/step
# Epoch 38/38
# 34/34 - 0s - loss: 9.7280 - accuracy: 0.5285 - 415ms/epoch - 12ms/step
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/38
# 34/34 - 2s - loss: 78.3934 - accuracy: 0.4139 - 2s/epoch - 62ms/step
# Epoch 2/38
# 34/34 - 0s - loss: 51.7094 - accuracy: 0.4934 - 420ms/epoch - 12ms/step
# Epoch 3/38
# 34/34 - 0s - loss: 39.9070 - accuracy: 0.5094 - 419ms/epoch - 12ms/step
# Epoch 4/38
# 34/34 - 0s - loss: 32.7085 - accuracy: 0.5052 - 430ms/epoch - 13ms/step
# Epoch 5/38
# 34/34 - 0s - loss: 29.6176 - accuracy: 0.4868 - 416ms/epoch - 12ms/step
# Epoch 6/38
# 34/34 - 0s - loss: 25.1594 - accuracy: 0.5143 - 416ms/epoch - 12ms/step
# Epoch 7/38
# 34/34 - 0s - loss: 22.3373 - accuracy: 0.5252 - 412ms/epoch - 12ms/step
# Epoch 8/38
# 34/34 - 0s - loss: 17.5317 - accuracy: 0.5161 - 408ms/epoch - 12ms/step
# Epoch 9/38
# 34/34 - 0s - loss: 24.1982 - accuracy: 0.4699 - 405ms/epoch - 12ms/step
# Epoch 10/38
# 34/34 - 0s - loss: 21.1795 - accuracy: 0.5148 - 431ms/epoch - 13ms/step
# Epoch 11/38
# 34/34 - 0s - loss: 20.1521 - accuracy: 0.5009 - 420ms/epoch - 12ms/step
# Epoch 12/38
# 34/34 - 0s - loss: 16.7269 - accuracy: 0.5119 - 439ms/epoch - 13ms/step
# Epoch 13/38
# 34/34 - 0s - loss: 16.5724 - accuracy: 0.5034 - 430ms/epoch - 13ms/step
# Epoch 14/38
# 34/34 - 0s - loss: 17.2871 - accuracy: 0.4916 - 422ms/epoch - 12ms/step
# Epoch 15/38
# 34/34 - 0s - loss: 17.6262 - accuracy: 0.4837 - 430ms/epoch - 13ms/step
# Epoch 16/38
# 34/34 - 0s - loss: 16.5618 - accuracy: 0.5142 - 432ms/epoch - 13ms/step
# Epoch 17/38
# 34/34 - 0s - loss: 12.9903 - accuracy: 0.5261 - 430ms/epoch - 13ms/step
# Epoch 18/38
# 34/34 - 0s - loss: 10.6780 - accuracy: 0.5106 - 427ms/epoch - 13ms/step
# Epoch 19/38
# 34/34 - 0s - loss: 15.3326 - accuracy: 0.5005 - 427ms/epoch - 13ms/step
# Epoch 20/38
# 34/34 - 0s - loss: 14.0747 - accuracy: 0.4881 - 421ms/epoch - 12ms/step
# Epoch 21/38
# 34/34 - 0s - loss: 14.5702 - accuracy: 0.5075 - 416ms/epoch - 12ms/step
# Epoch 22/38
# 34/34 - 0s - loss: 18.4777 - accuracy: 0.4879 - 421ms/epoch - 12ms/step
# Epoch 23/38
# 34/34 - 0s - loss: 15.2807 - accuracy: 0.4942 - 414ms/epoch - 12ms/step
# Epoch 24/38
# 34/34 - 0s - loss: 12.4988 - accuracy: 0.4975 - 427ms/epoch - 13ms/step
# Epoch 25/38
# 34/34 - 0s - loss: 15.1725 - accuracy: 0.4896 - 430ms/epoch - 13ms/step
# Epoch 26/38
# 34/34 - 0s - loss: 14.1295 - accuracy: 0.4980 - 420ms/epoch - 12ms/step
# Epoch 27/38
# 34/34 - 0s - loss: 12.6279 - accuracy: 0.4941 - 432ms/epoch - 13ms/step
# Epoch 28/38
# 34/34 - 0s - loss: 15.8837 - accuracy: 0.5095 - 415ms/epoch - 12ms/step
# Epoch 29/38
# 34/34 - 0s - loss: 12.3883 - accuracy: 0.5079 - 444ms/epoch - 13ms/step
# Epoch 30/38
# 34/34 - 0s - loss: 11.8842 - accuracy: 0.5003 - 427ms/epoch - 13ms/step
# Epoch 31/38
# 34/34 - 0s - loss: 9.3365 - accuracy: 0.5251 - 417ms/epoch - 12ms/step
# Epoch 32/38
# 34/34 - 0s - loss: 14.1273 - accuracy: 0.4899 - 427ms/epoch - 13ms/step
# Epoch 33/38
# 34/34 - 0s - loss: 13.8073 - accuracy: 0.4911 - 441ms/epoch - 13ms/step
# Epoch 34/38
# 34/34 - 0s - loss: 11.7338 - accuracy: 0.5223 - 440ms/epoch - 13ms/step
# Epoch 35/38
# 34/34 - 0s - loss: 10.6187 - accuracy: 0.4946 - 424ms/epoch - 12ms/step
# Epoch 36/38
# 34/34 - 0s - loss: 12.4141 - accuracy: 0.4868 - 419ms/epoch - 12ms/step
# Epoch 37/38
# 34/34 - 0s - loss: 9.3644 - accuracy: 0.5071 - 429ms/epoch - 13ms/step
# Epoch 37: early stopping
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/38
# 34/34 - 2s - loss: 81.3194 - accuracy: 0.4265 - 2s/epoch - 60ms/step
# Epoch 2/38
# 34/34 - 0s - loss: 41.3660 - accuracy: 0.5137 - 430ms/epoch - 13ms/step
# Epoch 3/38
# 34/34 - 0s - loss: 30.7015 - accuracy: 0.5001 - 418ms/epoch - 12ms/step
# Epoch 4/38
# 34/34 - 0s - loss: 24.0958 - accuracy: 0.5229 - 420ms/epoch - 12ms/step
# Epoch 5/38
# 34/34 - 0s - loss: 20.1617 - accuracy: 0.5163 - 418ms/epoch - 12ms/step
# Epoch 6/38
# 34/34 - 0s - loss: 15.3808 - accuracy: 0.5273 - 406ms/epoch - 12ms/step
# Epoch 7/38
# 34/34 - 0s - loss: 15.3590 - accuracy: 0.5077 - 409ms/epoch - 12ms/step
# Epoch 8/38
# 34/34 - 0s - loss: 17.2826 - accuracy: 0.5224 - 403ms/epoch - 12ms/step
# Epoch 9/38
# 34/34 - 0s - loss: 17.0324 - accuracy: 0.5149 - 409ms/epoch - 12ms/step
# Epoch 10/38
# 34/34 - 0s - loss: 17.4735 - accuracy: 0.5114 - 416ms/epoch - 12ms/step
# Epoch 11/38
# 34/34 - 0s - loss: 15.1122 - accuracy: 0.5131 - 415ms/epoch - 12ms/step
# Epoch 12/38
# 34/34 - 0s - loss: 15.7101 - accuracy: 0.5236 - 415ms/epoch - 12ms/step
# Epoch 13/38
# 34/34 - 0s - loss: 13.7084 - accuracy: 0.5287 - 418ms/epoch - 12ms/step
# Epoch 14/38
# 34/34 - 0s - loss: 15.0784 - accuracy: 0.5029 - 420ms/epoch - 12ms/step
# Epoch 15/38
# 34/34 - 0s - loss: 13.9767 - accuracy: 0.5092 - 421ms/epoch - 12ms/step
# Epoch 16/38
# 34/34 - 0s - loss: 13.3828 - accuracy: 0.5036 - 411ms/epoch - 12ms/step
# Epoch 17/38
# 34/34 - 0s - loss: 12.1863 - accuracy: 0.5189 - 425ms/epoch - 13ms/step
# Epoch 18/38
# 34/34 - 0s - loss: 10.6257 - accuracy: 0.5171 - 415ms/epoch - 12ms/step
# Epoch 19/38
# 34/34 - 0s - loss: 12.1165 - accuracy: 0.5123 - 421ms/epoch - 12ms/step
# Epoch 20/38
# 34/34 - 0s - loss: 10.5256 - accuracy: 0.5343 - 415ms/epoch - 12ms/step
# Epoch 21/38
# 34/34 - 0s - loss: 8.8256 - accuracy: 0.5337 - 412ms/epoch - 12ms/step
# Epoch 22/38
# 34/34 - 0s - loss: 10.1502 - accuracy: 0.5236 - 421ms/epoch - 12ms/step
# Epoch 23/38
# 34/34 - 0s - loss: 9.8232 - accuracy: 0.4963 - 426ms/epoch - 13ms/step
# Epoch 24/38
# 34/34 - 0s - loss: 13.6853 - accuracy: 0.5172 - 419ms/epoch - 12ms/step
# Epoch 25/38
# 34/34 - 0s - loss: 12.9499 - accuracy: 0.5038 - 420ms/epoch - 12ms/step
# Epoch 26/38
# 34/34 - 0s - loss: 14.0140 - accuracy: 0.5022 - 414ms/epoch - 12ms/step
# Epoch 27/38
# 34/34 - 0s - loss: 11.7058 - accuracy: 0.5139 - 416ms/epoch - 12ms/step
# Epoch 28/38
# 34/34 - 0s - loss: 13.9266 - accuracy: 0.4929 - 423ms/epoch - 12ms/step
# Epoch 29/38
# 34/34 - 0s - loss: 14.5244 - accuracy: 0.5046 - 419ms/epoch - 12ms/step
# Epoch 30/38
# 34/34 - 0s - loss: 12.3227 - accuracy: 0.5086 - 444ms/epoch - 13ms/step
# Epoch 31/38
# 34/34 - 0s - loss: 12.5408 - accuracy: 0.4877 - 418ms/epoch - 12ms/step
# Epoch 32/38
# 34/34 - 0s - loss: 11.7807 - accuracy: 0.4975 - 421ms/epoch - 12ms/step
# Epoch 33/38
# 34/34 - 0s - loss: 12.6213 - accuracy: 0.4820 - 416ms/epoch - 12ms/step
# Epoch 34/38
# 34/34 - 0s - loss: 14.4024 - accuracy: 0.4927 - 412ms/epoch - 12ms/step
# Epoch 35/38
# 34/34 - 0s - loss: 12.1673 - accuracy: 0.4825 - 416ms/epoch - 12ms/step
# Epoch 36/38
# 34/34 - 0s - loss: 14.2543 - accuracy: 0.5005 - 412ms/epoch - 12ms/step
# Epoch 37/38
# 34/34 - 0s - loss: 13.5856 - accuracy: 0.4882 - 423ms/epoch - 12ms/step
# Epoch 38/38
# 34/34 - 0s - loss: 13.6679 - accuracy: 0.4974 - 417ms/epoch - 12ms/step
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/38
# 34/34 - 2s - loss: 71.8823 - accuracy: 0.4112 - 2s/epoch - 60ms/step
# Epoch 2/38
# 34/34 - 0s - loss: 48.0568 - accuracy: 0.4972 - 429ms/epoch - 13ms/step
# Epoch 3/38
# 34/34 - 0s - loss: 35.7225 - accuracy: 0.4722 - 417ms/epoch - 12ms/step
# Epoch 4/38
# 34/34 - 0s - loss: 32.3055 - accuracy: 0.5150 - 419ms/epoch - 12ms/step
# Epoch 5/38
# 34/34 - 0s - loss: 22.4034 - accuracy: 0.5275 - 425ms/epoch - 12ms/step
# Epoch 6/38
# 34/34 - 0s - loss: 21.0761 - accuracy: 0.5001 - 428ms/epoch - 13ms/step
# Epoch 7/38
# 34/34 - 0s - loss: 19.9266 - accuracy: 0.5052 - 427ms/epoch - 13ms/step
# Epoch 8/38
# 34/34 - 0s - loss: 19.8346 - accuracy: 0.5053 - 423ms/epoch - 12ms/step
# Epoch 9/38
# 34/34 - 0s - loss: 20.0351 - accuracy: 0.5253 - 417ms/epoch - 12ms/step
# Epoch 10/38
# 34/34 - 0s - loss: 17.5715 - accuracy: 0.5153 - 421ms/epoch - 12ms/step
# Epoch 11/38
# 34/34 - 0s - loss: 17.1764 - accuracy: 0.4856 - 434ms/epoch - 13ms/step
# Epoch 12/38
# 34/34 - 0s - loss: 17.1500 - accuracy: 0.4979 - 421ms/epoch - 12ms/step
# Epoch 13/38
# 34/34 - 0s - loss: 15.7411 - accuracy: 0.5086 - 419ms/epoch - 12ms/step
# Epoch 14/38
# 34/34 - 0s - loss: 15.2188 - accuracy: 0.5013 - 422ms/epoch - 12ms/step
# Epoch 15/38
# 34/34 - 0s - loss: 14.5853 - accuracy: 0.4980 - 411ms/epoch - 12ms/step
# Epoch 16/38
# 34/34 - 0s - loss: 18.1929 - accuracy: 0.4886 - 418ms/epoch - 12ms/step
# Epoch 17/38
# 34/34 - 0s - loss: 18.7767 - accuracy: 0.4832 - 416ms/epoch - 12ms/step
# Epoch 18/38
# 34/34 - 0s - loss: 14.4135 - accuracy: 0.5140 - 429ms/epoch - 13ms/step
# Epoch 19/38
# 34/34 - 0s - loss: 14.8997 - accuracy: 0.4962 - 407ms/epoch - 12ms/step
# Epoch 20/38
# 34/34 - 0s - loss: 13.5766 - accuracy: 0.4939 - 432ms/epoch - 13ms/step
# Epoch 21/38
# 34/34 - 0s - loss: 15.6767 - accuracy: 0.4765 - 413ms/epoch - 12ms/step
# Epoch 22/38
# 34/34 - 0s - loss: 17.3841 - accuracy: 0.4557 - 425ms/epoch - 13ms/step
# Epoch 23/38
# 34/34 - 0s - loss: 14.9506 - accuracy: 0.4653 - 417ms/epoch - 12ms/step
# Epoch 24/38
# 34/34 - 0s - loss: 16.6567 - accuracy: 0.4764 - 414ms/epoch - 12ms/step
# Epoch 25/38
# 34/34 - 0s - loss: 16.3105 - accuracy: 0.4566 - 416ms/epoch - 12ms/step
# Epoch 25: early stopping
# 115/115 [==============================] - 0s 2ms/step
# | 3         | 0.4679    | 4.105     | 435.6     | 0.1997    | 0.1543    | 37.77     | 1.093     | 2.215     | 1.341     | 0.0744    | 47.96     | 0.9656    | 5.659     |
# Epoch 1/24
# 65/65 - 1s - loss: 3.3123 - accuracy: 0.4824 - 1s/epoch - 19ms/step
# Epoch 2/24
# 65/65 - 0s - loss: 1.0542 - accuracy: 0.6358 - 490ms/epoch - 8ms/step
# Epoch 3/24
# 65/65 - 0s - loss: 0.9488 - accuracy: 0.6850 - 496ms/epoch - 8ms/step
# Epoch 4/24
# 65/65 - 1s - loss: 0.8801 - accuracy: 0.7114 - 536ms/epoch - 8ms/step
# Epoch 5/24
# 65/65 - 0s - loss: 0.8525 - accuracy: 0.7209 - 470ms/epoch - 7ms/step
# Epoch 6/24
# 65/65 - 0s - loss: 0.8236 - accuracy: 0.7255 - 464ms/epoch - 7ms/step
# Epoch 7/24
# 65/65 - 0s - loss: 0.8044 - accuracy: 0.7319 - 464ms/epoch - 7ms/step
# Epoch 8/24
# 65/65 - 0s - loss: 0.7812 - accuracy: 0.7386 - 469ms/epoch - 7ms/step
# Epoch 9/24
# 65/65 - 0s - loss: 0.7688 - accuracy: 0.7415 - 475ms/epoch - 7ms/step
# Epoch 10/24
# 65/65 - 0s - loss: 0.7623 - accuracy: 0.7443 - 469ms/epoch - 7ms/step
# Epoch 11/24
# 65/65 - 0s - loss: 0.7483 - accuracy: 0.7493 - 465ms/epoch - 7ms/step
# Epoch 12/24
# 65/65 - 0s - loss: 0.7398 - accuracy: 0.7513 - 472ms/epoch - 7ms/step
# Epoch 13/24
# 65/65 - 1s - loss: 0.7335 - accuracy: 0.7507 - 511ms/epoch - 8ms/step
# Epoch 14/24
# 65/65 - 1s - loss: 0.7266 - accuracy: 0.7528 - 509ms/epoch - 8ms/step
# Epoch 15/24
# 65/65 - 0s - loss: 0.7095 - accuracy: 0.7582 - 476ms/epoch - 7ms/step
# Epoch 16/24
# 65/65 - 0s - loss: 0.7143 - accuracy: 0.7553 - 481ms/epoch - 7ms/step
# Epoch 17/24
# 65/65 - 0s - loss: 0.6946 - accuracy: 0.7612 - 480ms/epoch - 7ms/step
# Epoch 18/24
# 65/65 - 0s - loss: 0.6878 - accuracy: 0.7619 - 466ms/epoch - 7ms/step
# Epoch 19/24
# 65/65 - 0s - loss: 0.6794 - accuracy: 0.7663 - 475ms/epoch - 7ms/step
# Epoch 20/24
# 65/65 - 0s - loss: 0.6667 - accuracy: 0.7674 - 479ms/epoch - 7ms/step
# Epoch 21/24
# 65/65 - 0s - loss: 0.6759 - accuracy: 0.7616 - 465ms/epoch - 7ms/step
# Epoch 22/24
# 65/65 - 0s - loss: 0.6599 - accuracy: 0.7661 - 476ms/epoch - 7ms/step
# Epoch 23/24
# 65/65 - 1s - loss: 0.6530 - accuracy: 0.7706 - 505ms/epoch - 8ms/step
# Epoch 24/24
# 65/65 - 0s - loss: 0.6387 - accuracy: 0.7772 - 471ms/epoch - 7ms/step
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/24
# 65/65 - 1s - loss: 2.3117 - accuracy: 0.5323 - 1s/epoch - 20ms/step
# Epoch 2/24
# 65/65 - 0s - loss: 0.9123 - accuracy: 0.6951 - 485ms/epoch - 7ms/step
# Epoch 3/24
# 65/65 - 0s - loss: 0.8100 - accuracy: 0.7251 - 463ms/epoch - 7ms/step
# Epoch 4/24
# 65/65 - 0s - loss: 0.7904 - accuracy: 0.7275 - 477ms/epoch - 7ms/step
# Epoch 5/24
# 65/65 - 0s - loss: 0.7482 - accuracy: 0.7412 - 463ms/epoch - 7ms/step
# Epoch 6/24
# 65/65 - 0s - loss: 0.7172 - accuracy: 0.7533 - 484ms/epoch - 7ms/step
# Epoch 7/24
# 65/65 - 0s - loss: 0.7078 - accuracy: 0.7557 - 477ms/epoch - 7ms/step
# Epoch 8/24
# 65/65 - 0s - loss: 0.6938 - accuracy: 0.7593 - 495ms/epoch - 8ms/step
# Epoch 9/24
# 65/65 - 0s - loss: 0.6833 - accuracy: 0.7622 - 479ms/epoch - 7ms/step
# Epoch 10/24
# 65/65 - 0s - loss: 0.6748 - accuracy: 0.7649 - 480ms/epoch - 7ms/step
# Epoch 11/24
# 65/65 - 0s - loss: 0.6699 - accuracy: 0.7650 - 464ms/epoch - 7ms/step
# Epoch 12/24
# 65/65 - 0s - loss: 0.6541 - accuracy: 0.7711 - 470ms/epoch - 7ms/step
# Epoch 13/24
# 65/65 - 0s - loss: 0.6398 - accuracy: 0.7763 - 469ms/epoch - 7ms/step
# Epoch 14/24
# 65/65 - 0s - loss: 0.6409 - accuracy: 0.7767 - 466ms/epoch - 7ms/step
# Epoch 15/24
# 65/65 - 1s - loss: 0.6406 - accuracy: 0.7727 - 511ms/epoch - 8ms/step
# Epoch 16/24
# 65/65 - 0s - loss: 0.6214 - accuracy: 0.7809 - 498ms/epoch - 8ms/step
# Epoch 17/24
# 65/65 - 0s - loss: 0.6157 - accuracy: 0.7808 - 468ms/epoch - 7ms/step
# Epoch 18/24
# 65/65 - 0s - loss: 0.6135 - accuracy: 0.7806 - 468ms/epoch - 7ms/step
# Epoch 19/24
# 65/65 - 0s - loss: 0.6122 - accuracy: 0.7781 - 468ms/epoch - 7ms/step
# Epoch 20/24
# 65/65 - 0s - loss: 0.6060 - accuracy: 0.7842 - 487ms/epoch - 7ms/step
# Epoch 21/24
# 65/65 - 0s - loss: 0.5955 - accuracy: 0.7859 - 465ms/epoch - 7ms/step
# Epoch 22/24
# 65/65 - 0s - loss: 0.5944 - accuracy: 0.7855 - 468ms/epoch - 7ms/step
# Epoch 23/24
# 65/65 - 0s - loss: 0.5871 - accuracy: 0.7879 - 473ms/epoch - 7ms/step
# Epoch 24/24
# 65/65 - 0s - loss: 0.5751 - accuracy: 0.7911 - 463ms/epoch - 7ms/step
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/24
# 65/65 - 1s - loss: 2.1845 - accuracy: 0.5429 - 1s/epoch - 19ms/step
# Epoch 2/24
# 65/65 - 0s - loss: 0.9086 - accuracy: 0.6818 - 480ms/epoch - 7ms/step
# Epoch 3/24
# 65/65 - 0s - loss: 0.8202 - accuracy: 0.7219 - 495ms/epoch - 8ms/step
# Epoch 4/24
# 65/65 - 1s - loss: 0.7772 - accuracy: 0.7322 - 536ms/epoch - 8ms/step
# Epoch 5/24
# 65/65 - 1s - loss: 0.7348 - accuracy: 0.7467 - 548ms/epoch - 8ms/step
# Epoch 6/24
# 65/65 - 1s - loss: 0.7071 - accuracy: 0.7591 - 542ms/epoch - 8ms/step
# Epoch 7/24
# 65/65 - 1s - loss: 0.7040 - accuracy: 0.7574 - 546ms/epoch - 8ms/step
# Epoch 8/24
# 65/65 - 1s - loss: 0.6834 - accuracy: 0.7652 - 558ms/epoch - 9ms/step
# Epoch 9/24
# 65/65 - 0s - loss: 0.6770 - accuracy: 0.7642 - 481ms/epoch - 7ms/step
# Epoch 10/24
# 65/65 - 0s - loss: 0.6652 - accuracy: 0.7684 - 462ms/epoch - 7ms/step
# Epoch 11/24
# 65/65 - 0s - loss: 0.6664 - accuracy: 0.7660 - 461ms/epoch - 7ms/step
# Epoch 12/24
# 65/65 - 0s - loss: 0.6516 - accuracy: 0.7717 - 475ms/epoch - 7ms/step
# Epoch 13/24
# 65/65 - 0s - loss: 0.6429 - accuracy: 0.7758 - 466ms/epoch - 7ms/step
# Epoch 14/24
# 65/65 - 0s - loss: 0.6382 - accuracy: 0.7725 - 483ms/epoch - 7ms/step
# Epoch 15/24
# 65/65 - 0s - loss: 0.6268 - accuracy: 0.7820 - 470ms/epoch - 7ms/step
# Epoch 16/24
# 65/65 - 0s - loss: 0.6261 - accuracy: 0.7819 - 478ms/epoch - 7ms/step
# Epoch 17/24
# 65/65 - 0s - loss: 0.6290 - accuracy: 0.7840 - 493ms/epoch - 8ms/step
# Epoch 18/24
# 65/65 - 0s - loss: 0.6211 - accuracy: 0.7819 - 477ms/epoch - 7ms/step
# Epoch 19/24
# 65/65 - 0s - loss: 0.6110 - accuracy: 0.7832 - 487ms/epoch - 7ms/step
# Epoch 20/24
# 65/65 - 0s - loss: 0.6111 - accuracy: 0.7857 - 464ms/epoch - 7ms/step
# Epoch 21/24
# 65/65 - 0s - loss: 0.5992 - accuracy: 0.7892 - 471ms/epoch - 7ms/step
# Epoch 22/24
# 65/65 - 0s - loss: 0.6005 - accuracy: 0.7899 - 467ms/epoch - 7ms/step
# Epoch 23/24
# 65/65 - 0s - loss: 0.5915 - accuracy: 0.7921 - 464ms/epoch - 7ms/step
# Epoch 24/24
# 65/65 - 0s - loss: 0.5907 - accuracy: 0.7892 - 490ms/epoch - 8ms/step
# 115/115 [==============================] - 1s 2ms/step
# Epoch 1/24
# 65/65 - 1s - loss: 1.7661 - accuracy: 0.5616 - 1s/epoch - 20ms/step
# Epoch 2/24
# 65/65 - 1s - loss: 0.9463 - accuracy: 0.6766 - 504ms/epoch - 8ms/step
# Epoch 3/24
# 65/65 - 0s - loss: 0.8340 - accuracy: 0.7269 - 488ms/epoch - 8ms/step
# Epoch 4/24
# 65/65 - 0s - loss: 0.8074 - accuracy: 0.7305 - 495ms/epoch - 8ms/step
# Epoch 5/24
# 65/65 - 0s - loss: 0.7763 - accuracy: 0.7386 - 490ms/epoch - 8ms/step
# Epoch 6/24
# 65/65 - 0s - loss: 0.7624 - accuracy: 0.7436 - 477ms/epoch - 7ms/step
# Epoch 7/24
# 65/65 - 0s - loss: 0.7299 - accuracy: 0.7534 - 479ms/epoch - 7ms/step
# Epoch 8/24
# 65/65 - 0s - loss: 0.7304 - accuracy: 0.7499 - 471ms/epoch - 7ms/step
# Epoch 9/24
# 65/65 - 0s - loss: 0.7024 - accuracy: 0.7584 - 494ms/epoch - 8ms/step
# Epoch 10/24
# 65/65 - 0s - loss: 0.6942 - accuracy: 0.7599 - 486ms/epoch - 7ms/step
# Epoch 11/24
# 65/65 - 0s - loss: 0.6823 - accuracy: 0.7633 - 477ms/epoch - 7ms/step
# Epoch 12/24
# 65/65 - 0s - loss: 0.6701 - accuracy: 0.7657 - 491ms/epoch - 8ms/step
# Epoch 13/24
# 65/65 - 0s - loss: 0.6633 - accuracy: 0.7665 - 477ms/epoch - 7ms/step
# Epoch 14/24
# 65/65 - 0s - loss: 0.6646 - accuracy: 0.7684 - 481ms/epoch - 7ms/step
# Epoch 15/24
# 65/65 - 0s - loss: 0.6528 - accuracy: 0.7714 - 487ms/epoch - 7ms/step
# Epoch 16/24
# 65/65 - 1s - loss: 0.6451 - accuracy: 0.7718 - 504ms/epoch - 8ms/step
# Epoch 17/24
# 65/65 - 1s - loss: 0.6437 - accuracy: 0.7721 - 511ms/epoch - 8ms/step
# Epoch 18/24
# 65/65 - 1s - loss: 0.6367 - accuracy: 0.7760 - 503ms/epoch - 8ms/step
# Epoch 19/24
# 65/65 - 1s - loss: 0.6237 - accuracy: 0.7785 - 509ms/epoch - 8ms/step
# Epoch 20/24
# 65/65 - 0s - loss: 0.6228 - accuracy: 0.7779 - 481ms/epoch - 7ms/step
# Epoch 21/24
# 65/65 - 0s - loss: 0.6197 - accuracy: 0.7802 - 472ms/epoch - 7ms/step
# Epoch 22/24
# 65/65 - 0s - loss: 0.6161 - accuracy: 0.7802 - 485ms/epoch - 7ms/step
# Epoch 23/24
# 65/65 - 1s - loss: 0.6027 - accuracy: 0.7857 - 511ms/epoch - 8ms/step
# Epoch 24/24
# 65/65 - 0s - loss: 0.5955 - accuracy: 0.7879 - 468ms/epoch - 7ms/step
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/24
# 65/65 - 1s - loss: 1.7250 - accuracy: 0.5707 - 1s/epoch - 19ms/step
# Epoch 2/24
# 65/65 - 0s - loss: 0.9050 - accuracy: 0.6965 - 481ms/epoch - 7ms/step
# Epoch 3/24
# 65/65 - 0s - loss: 0.8204 - accuracy: 0.7213 - 497ms/epoch - 8ms/step
# Epoch 4/24
# 65/65 - 0s - loss: 0.7841 - accuracy: 0.7373 - 478ms/epoch - 7ms/step
# Epoch 5/24
# 65/65 - 0s - loss: 0.7667 - accuracy: 0.7382 - 455ms/epoch - 7ms/step
# Epoch 6/24
# 65/65 - 0s - loss: 0.7408 - accuracy: 0.7469 - 459ms/epoch - 7ms/step
# Epoch 7/24
# 65/65 - 0s - loss: 0.7135 - accuracy: 0.7556 - 457ms/epoch - 7ms/step
# Epoch 8/24
# 65/65 - 0s - loss: 0.7121 - accuracy: 0.7523 - 463ms/epoch - 7ms/step
# Epoch 9/24
# 65/65 - 0s - loss: 0.7013 - accuracy: 0.7591 - 484ms/epoch - 7ms/step
# Epoch 10/24
# 65/65 - 0s - loss: 0.6859 - accuracy: 0.7604 - 466ms/epoch - 7ms/step
# Epoch 11/24
# 65/65 - 0s - loss: 0.6739 - accuracy: 0.7640 - 485ms/epoch - 7ms/step
# Epoch 12/24
# 65/65 - 0s - loss: 0.6690 - accuracy: 0.7666 - 486ms/epoch - 7ms/step
# Epoch 13/24
# 65/65 - 0s - loss: 0.6537 - accuracy: 0.7714 - 500ms/epoch - 8ms/step
# Epoch 14/24
# 65/65 - 0s - loss: 0.6548 - accuracy: 0.7736 - 468ms/epoch - 7ms/step
# Epoch 15/24
# 65/65 - 1s - loss: 0.6445 - accuracy: 0.7760 - 584ms/epoch - 9ms/step
# Epoch 16/24
# 65/65 - 0s - loss: 0.6347 - accuracy: 0.7788 - 470ms/epoch - 7ms/step
# Epoch 17/24
# 65/65 - 0s - loss: 0.6389 - accuracy: 0.7753 - 465ms/epoch - 7ms/step
# Epoch 18/24
# 65/65 - 0s - loss: 0.6207 - accuracy: 0.7811 - 467ms/epoch - 7ms/step
# Epoch 19/24
# 65/65 - 0s - loss: 0.6254 - accuracy: 0.7796 - 475ms/epoch - 7ms/step
# Epoch 20/24
# 65/65 - 0s - loss: 0.6136 - accuracy: 0.7887 - 468ms/epoch - 7ms/step
# Epoch 21/24
# 65/65 - 0s - loss: 0.6106 - accuracy: 0.7851 - 497ms/epoch - 8ms/step
# Epoch 22/24
# 65/65 - 0s - loss: 0.6004 - accuracy: 0.7903 - 481ms/epoch - 7ms/step
# Epoch 23/24
# 65/65 - 0s - loss: 0.6110 - accuracy: 0.7824 - 465ms/epoch - 7ms/step
# Epoch 24/24
# 65/65 - 0s - loss: 0.5932 - accuracy: 0.7937 - 464ms/epoch - 7ms/step
# 115/115 [==============================] - 0s 2ms/step
# | 4         | 0.7306    | 2.742     | 229.3     | 0.6842    | 0.132     | 23.66     | 1.99      | 1.069     | 2.819     | 0.2662    | 36.5      | 0.3117    | 3.64      |
# Epoch 1/48
# 58/58 - 2s - loss: 172.3565 - accuracy: 0.4397 - 2s/epoch - 31ms/step
# Epoch 2/48
# 58/58 - 0s - loss: 25.7142 - accuracy: 0.4241 - 401ms/epoch - 7ms/step
# Epoch 3/48
# 58/58 - 0s - loss: 24.1319 - accuracy: 0.4218 - 433ms/epoch - 7ms/step
# Epoch 4/48
# 58/58 - 0s - loss: 81.9261 - accuracy: 0.4084 - 429ms/epoch - 7ms/step
# Epoch 5/48
# 58/58 - 0s - loss: 12.7749 - accuracy: 0.4404 - 393ms/epoch - 7ms/step
# Epoch 6/48
# 58/58 - 0s - loss: 25.4885 - accuracy: 0.4257 - 429ms/epoch - 7ms/step
# Epoch 7/48
# 58/58 - 0s - loss: 3439.8394 - accuracy: 0.4269 - 462ms/epoch - 8ms/step
# Epoch 8/48
# 58/58 - 0s - loss: 742.0126 - accuracy: 0.4354 - 407ms/epoch - 7ms/step
# Epoch 9/48
# 58/58 - 0s - loss: 12.6696 - accuracy: 0.4297 - 397ms/epoch - 7ms/step
# Epoch 10/48
# 58/58 - 0s - loss: 13.7953 - accuracy: 0.4348 - 441ms/epoch - 8ms/step
# Epoch 11/48
# 58/58 - 0s - loss: 14.1684 - accuracy: 0.4381 - 419ms/epoch - 7ms/step
# Epoch 12/48
# 58/58 - 0s - loss: 13.2905 - accuracy: 0.4231 - 416ms/epoch - 7ms/step
# Epoch 13/48
# 58/58 - 0s - loss: 13.5865 - accuracy: 0.4211 - 427ms/epoch - 7ms/step
# Epoch 14/48
# 58/58 - 0s - loss: 14.5849 - accuracy: 0.4171 - 436ms/epoch - 8ms/step
# Epoch 15/48
# 58/58 - 0s - loss: 15.2484 - accuracy: 0.4112 - 411ms/epoch - 7ms/step
# Epoch 16/48
# 58/58 - 0s - loss: 14.7094 - accuracy: 0.4319 - 496ms/epoch - 9ms/step
# Epoch 17/48
# 58/58 - 0s - loss: 96.9241 - accuracy: 0.4304 - 467ms/epoch - 8ms/step
# Epoch 18/48
# 58/58 - 0s - loss: 13.9243 - accuracy: 0.4111 - 490ms/epoch - 8ms/step
# Epoch 19/48
# 58/58 - 0s - loss: 13.9869 - accuracy: 0.4314 - 472ms/epoch - 8ms/step
# Epoch 20/48
# 58/58 - 0s - loss: 13.7828 - accuracy: 0.4203 - 431ms/epoch - 7ms/step
# Epoch 21/48
# 58/58 - 0s - loss: 14.2114 - accuracy: 0.4047 - 442ms/epoch - 8ms/step
# Epoch 22/48
# 58/58 - 0s - loss: 14.0246 - accuracy: 0.4312 - 434ms/epoch - 7ms/step
# Epoch 23/48
# 58/58 - 0s - loss: 14.7361 - accuracy: 0.4242 - 480ms/epoch - 8ms/step
# Epoch 24/48
# 58/58 - 0s - loss: 15.7584 - accuracy: 0.4015 - 455ms/epoch - 8ms/step
# Epoch 25/48
# 58/58 - 1s - loss: 13.9141 - accuracy: 0.4434 - 505ms/epoch - 9ms/step
# Epoch 26/48
# 58/58 - 0s - loss: 15.3497 - accuracy: 0.4159 - 425ms/epoch - 7ms/step
# Epoch 27/48
# 58/58 - 0s - loss: 13.4378 - accuracy: 0.4431 - 464ms/epoch - 8ms/step
# Epoch 28/48
# 58/58 - 0s - loss: 13.6468 - accuracy: 0.4269 - 456ms/epoch - 8ms/step
# Epoch 29/48
# 58/58 - 0s - loss: 15.2611 - accuracy: 0.4113 - 445ms/epoch - 8ms/step
# Epoch 30/48
# 58/58 - 0s - loss: 14.3496 - accuracy: 0.4244 - 465ms/epoch - 8ms/step
# Epoch 31/48
# 58/58 - 0s - loss: 15.4771 - accuracy: 0.4204 - 482ms/epoch - 8ms/step
# Epoch 32/48
# 58/58 - 0s - loss: 14.2495 - accuracy: 0.4147 - 438ms/epoch - 8ms/step
# Epoch 33/48
# 58/58 - 0s - loss: 14.1662 - accuracy: 0.4241 - 422ms/epoch - 7ms/step
# Epoch 34/48
# 58/58 - 0s - loss: 15.0066 - accuracy: 0.4237 - 445ms/epoch - 8ms/step
# Epoch 35/48
# 58/58 - 0s - loss: 14.4121 - accuracy: 0.4201 - 460ms/epoch - 8ms/step
# Epoch 36/48
# 58/58 - 0s - loss: 14.3428 - accuracy: 0.4258 - 475ms/epoch - 8ms/step
# Epoch 37/48
# 58/58 - 0s - loss: 13.8211 - accuracy: 0.4284 - 432ms/epoch - 7ms/step
# Epoch 38/48
# 58/58 - 0s - loss: 13.7822 - accuracy: 0.4303 - 431ms/epoch - 7ms/step
# Epoch 39/48
# 58/58 - 0s - loss: 14.3560 - accuracy: 0.4146 - 452ms/epoch - 8ms/step
# Epoch 40/48
# 58/58 - 0s - loss: 14.0278 - accuracy: 0.4414 - 446ms/epoch - 8ms/step
# Epoch 41/48
# 58/58 - 0s - loss: 14.7919 - accuracy: 0.4164 - 434ms/epoch - 7ms/step
# Epoch 42/48
# 58/58 - 0s - loss: 14.6385 - accuracy: 0.4062 - 444ms/epoch - 8ms/step
# Epoch 43/48
# 58/58 - 0s - loss: 13.7038 - accuracy: 0.4363 - 454ms/epoch - 8ms/step
# Epoch 44/48
# 58/58 - 0s - loss: 15.1199 - accuracy: 0.4152 - 452ms/epoch - 8ms/step
# Epoch 45/48
# 58/58 - 0s - loss: 14.7091 - accuracy: 0.4259 - 433ms/epoch - 7ms/step
# Epoch 45: early stopping
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/48
# 58/58 - 2s - loss: 83.0864 - accuracy: 0.4478 - 2s/epoch - 30ms/step
# Epoch 2/48
# 58/58 - 0s - loss: 32.2668 - accuracy: 0.4233 - 401ms/epoch - 7ms/step
# Epoch 3/48
# 58/58 - 0s - loss: 13.4501 - accuracy: 0.4340 - 390ms/epoch - 7ms/step
# Epoch 4/48
# 58/58 - 0s - loss: 14.6355 - accuracy: 0.4214 - 386ms/epoch - 7ms/step
# Epoch 5/48
# ...
# Epoch 3/48
# 37/37 - 1s - loss: 0.7936 - accuracy: 0.7348 - 1s/epoch - 33ms/step
# Epoch 4/48
# 37/37 - 1s - loss: 0.8053 - accuracy: 0.7282 - 1s/epoch - 32ms/step
# Epoch 5/48
# 37/37 - 1s - loss: 0.7425 - accuracy: 0.7506 - 1s/epoch - 33ms/step
# Epoch 6/48
# 37/37 - 1s - loss: 0.7223 - accuracy: 0.7566 - 1s/epoch - 33ms/step
# Epoch 7/48
# 37/37 - 1s - loss: 0.7038 - accuracy: 0.7608 - 1s/epoch - 34ms/step
# Epoch 8/48
# 37/37 - 1s - loss: 0.6869 - accuracy: 0.7662 - 1s/epoch - 34ms/step
# Epoch 9/48
# 37/37 - 1s - loss: 0.6765 - accuracy: 0.7697 - 1s/epoch - 33ms/step
# Epoch 10/48
# 37/37 - 1s - loss: 0.6818 - accuracy: 0.7667 - 1s/epoch - 32ms/step
# Epoch 11/48
# 37/37 - 1s - loss: 0.6616 - accuracy: 0.7757 - 1s/epoch - 33ms/step
# Epoch 12/48
# 37/37 - 1s - loss: 0.6445 - accuracy: 0.7809 - 1s/epoch - 32ms/step
# Epoch 13/48
# 37/37 - 1s - loss: 0.6410 - accuracy: 0.7797 - 1s/epoch - 33ms/step
# Epoch 14/48
# 37/37 - 1s - loss: 0.6275 - accuracy: 0.7840 - 1s/epoch - 33ms/step
# Epoch 15/48
# 37/37 - 1s - loss: 0.6286 - accuracy: 0.7823 - 1s/epoch - 33ms/step
# Epoch 16/48
# 37/37 - 1s - loss: 0.6220 - accuracy: 0.7840 - 1s/epoch - 34ms/step
# Epoch 17/48
# 37/37 - 1s - loss: 0.6102 - accuracy: 0.7881 - 1s/epoch - 33ms/step
# Epoch 18/48
# 37/37 - 1s - loss: 0.6164 - accuracy: 0.7850 - 1s/epoch - 36ms/step
# Epoch 19/48
# 37/37 - 1s - loss: 0.6006 - accuracy: 0.7926 - 1s/epoch - 32ms/step
# Epoch 20/48
# 37/37 - 1s - loss: 0.5986 - accuracy: 0.7903 - 1s/epoch - 32ms/step
# Epoch 21/48
# 37/37 - 1s - loss: 0.5841 - accuracy: 0.7971 - 1s/epoch - 32ms/step
# Epoch 22/48
# 37/37 - 1s - loss: 0.5905 - accuracy: 0.7911 - 1s/epoch - 33ms/step
# Epoch 23/48
# 37/37 - 1s - loss: 0.5851 - accuracy: 0.7938 - 1s/epoch - 33ms/step
# Epoch 24/48
# 37/37 - 1s - loss: 0.5750 - accuracy: 0.8017 - 1s/epoch - 32ms/step
# Epoch 25/48
# 37/37 - 1s - loss: 0.5840 - accuracy: 0.7946 - 1s/epoch - 34ms/step
# Epoch 26/48
# 37/37 - 1s - loss: 0.5652 - accuracy: 0.8015 - 1s/epoch - 32ms/step
# Epoch 27/48
# 37/37 - 1s - loss: 0.5660 - accuracy: 0.8016 - 1s/epoch - 33ms/step
# Epoch 28/48
# 37/37 - 1s - loss: 0.5594 - accuracy: 0.8015 - 1s/epoch - 33ms/step
# Epoch 29/48
# 37/37 - 1s - loss: 0.5611 - accuracy: 0.8021 - 1s/epoch - 32ms/step
# Epoch 30/48
# 37/37 - 1s - loss: 0.5435 - accuracy: 0.8073 - 1s/epoch - 34ms/step
# Epoch 31/48
# 37/37 - 1s - loss: 0.5382 - accuracy: 0.8068 - 1s/epoch - 36ms/step
# Epoch 32/48
# 37/37 - 1s - loss: 0.5488 - accuracy: 0.8030 - 1s/epoch - 35ms/step
# Epoch 33/48
# 37/37 - 1s - loss: 0.5518 - accuracy: 0.8048 - 1s/epoch - 36ms/step
# Epoch 34/48
# 37/37 - 1s - loss: 0.5452 - accuracy: 0.8040 - 1s/epoch - 34ms/step
# Epoch 35/48
# 37/37 - 1s - loss: 0.5140 - accuracy: 0.8189 - 1s/epoch - 33ms/step
# Epoch 36/48
# 37/37 - 1s - loss: 0.5444 - accuracy: 0.8056 - 1s/epoch - 32ms/step
# Epoch 37/48
# 37/37 - 1s - loss: 0.5218 - accuracy: 0.8124 - 1s/epoch - 34ms/step
# Epoch 38/48
# 37/37 - 1s - loss: 0.5256 - accuracy: 0.8130 - 1s/epoch - 33ms/step
# Epoch 39/48
# 37/37 - 1s - loss: 0.5262 - accuracy: 0.8095 - 1s/epoch - 36ms/step
# Epoch 40/48
# 37/37 - 1s - loss: 0.5277 - accuracy: 0.8123 - 1s/epoch - 36ms/step
# Epoch 41/48
# 37/37 - 1s - loss: 0.5284 - accuracy: 0.8106 - 1s/epoch - 37ms/step
# Epoch 42/48
# 37/37 - 1s - loss: 0.5263 - accuracy: 0.8145 - 1s/epoch - 34ms/step
# Epoch 43/48
# 37/37 - 1s - loss: 0.5270 - accuracy: 0.8139 - 1s/epoch - 33ms/step
# Epoch 44/48
# 37/37 - 1s - loss: 0.5140 - accuracy: 0.8160 - 1s/epoch - 33ms/step
# Epoch 45/48
# 37/37 - 1s - loss: 0.5153 - accuracy: 0.8175 - 1s/epoch - 32ms/step
# Epoch 46/48
# 37/37 - 1s - loss: 0.5149 - accuracy: 0.8184 - 1s/epoch - 32ms/step
# Epoch 47/48
# 37/37 - 1s - loss: 0.5111 - accuracy: 0.8192 - 1s/epoch - 32ms/step
# Epoch 48/48
# 37/37 - 1s - loss: 0.5072 - accuracy: 0.8210 - 1s/epoch - 32ms/step
# 115/115 [==============================] - 1s 6ms/step
# | 18        | 0.7853    | 7.829     | 405.3     | 0.2349    | 0.02314   | 48.3      | 2.239     | 1.884     | 1.461     | 0.1348    | 19.77     | 0.7608    | 0.192     |
# Epoch 1/28
# 64/64 - 4s - loss: 1.3111 - accuracy: 0.6172 - 4s/epoch - 57ms/step
# Epoch 2/28
# 64/64 - 1s - loss: 1.0179 - accuracy: 0.6502 - 1s/epoch - 16ms/step
# Epoch 3/28
# 64/64 - 1s - loss: 0.9545 - accuracy: 0.6758 - 1s/epoch - 16ms/step
# Epoch 4/28
# 64/64 - 1s - loss: 0.9120 - accuracy: 0.6929 - 1s/epoch - 16ms/step
# Epoch 5/28
# 64/64 - 1s - loss: 0.8512 - accuracy: 0.7047 - 1s/epoch - 16ms/step
# Epoch 6/28
# 64/64 - 1s - loss: 0.8023 - accuracy: 0.7211 - 1s/epoch - 17ms/step
# Epoch 7/28
# 64/64 - 1s - loss: 0.7648 - accuracy: 0.7296 - 1s/epoch - 17ms/step
# Epoch 8/28
# 64/64 - 1s - loss: 0.7345 - accuracy: 0.7439 - 1s/epoch - 16ms/step
# Epoch 9/28
# 64/64 - 1s - loss: 0.7065 - accuracy: 0.7544 - 1s/epoch - 16ms/step
# Epoch 10/28
# 64/64 - 1s - loss: 0.7043 - accuracy: 0.7569 - 980ms/epoch - 15ms/step
# Epoch 11/28
# 64/64 - 1s - loss: 0.6815 - accuracy: 0.7648 - 1s/epoch - 16ms/step
# Epoch 12/28
# 64/64 - 1s - loss: 0.6592 - accuracy: 0.7719 - 1s/epoch - 16ms/step
# Epoch 13/28
# 64/64 - 1s - loss: 0.6538 - accuracy: 0.7727 - 1s/epoch - 17ms/step
# Epoch 14/28
# 64/64 - 1s - loss: 0.6369 - accuracy: 0.7817 - 1s/epoch - 16ms/step
# Epoch 15/28
# 64/64 - 1s - loss: 0.6265 - accuracy: 0.7826 - 999ms/epoch - 16ms/step
# Epoch 16/28
# 64/64 - 1s - loss: 0.6087 - accuracy: 0.7871 - 1s/epoch - 16ms/step
# Epoch 17/28
# 64/64 - 1s - loss: 0.6133 - accuracy: 0.7868 - 978ms/epoch - 15ms/step
# Epoch 18/28
# 64/64 - 1s - loss: 0.5958 - accuracy: 0.7927 - 1s/epoch - 17ms/step
# Epoch 19/28
# 64/64 - 1s - loss: 0.5886 - accuracy: 0.7948 - 993ms/epoch - 16ms/step
# Epoch 20/28
# 64/64 - 1s - loss: 0.5730 - accuracy: 0.7996 - 1s/epoch - 16ms/step
# Epoch 21/28
# 64/64 - 1s - loss: 0.5677 - accuracy: 0.8013 - 1s/epoch - 17ms/step
# Epoch 22/28
# 64/64 - 1s - loss: 0.5606 - accuracy: 0.8049 - 1s/epoch - 16ms/step
# Epoch 23/28
# 64/64 - 1s - loss: 0.5496 - accuracy: 0.8056 - 1s/epoch - 16ms/step
# Epoch 24/28
# 64/64 - 1s - loss: 0.5490 - accuracy: 0.8065 - 1s/epoch - 16ms/step
# Epoch 25/28
# 64/64 - 1s - loss: 0.5473 - accuracy: 0.8056 - 1s/epoch - 16ms/step
# Epoch 26/28
# 64/64 - 1s - loss: 0.5445 - accuracy: 0.8067 - 537ms/epoch - 8ms/step
# Epoch 27/28
# 64/64 - 0s - loss: 0.5369 - accuracy: 0.8099 - 259ms/epoch - 4ms/step
# Epoch 28/28
# 64/64 - 0s - loss: 0.5265 - accuracy: 0.8140 - 261ms/epoch - 4ms/step
# 115/115 [==============================] - 0s 1ms/step
# Epoch 1/28
# 64/64 - 1s - loss: 1.2683 - accuracy: 0.6055 - 1s/epoch - 19ms/step
# Epoch 2/28
# 64/64 - 0s - loss: 0.9942 - accuracy: 0.6592 - 264ms/epoch - 4ms/step
# Epoch 3/28
# 64/64 - 0s - loss: 0.8896 - accuracy: 0.7085 - 257ms/epoch - 4ms/step
# Epoch 4/28
# 64/64 - 0s - loss: 0.8319 - accuracy: 0.7316 - 256ms/epoch - 4ms/step
# Epoch 5/28
# 64/64 - 0s - loss: 0.7902 - accuracy: 0.7420 - 254ms/epoch - 4ms/step
# Epoch 6/28
# 64/64 - 0s - loss: 0.7677 - accuracy: 0.7432 - 252ms/epoch - 4ms/step
# Epoch 7/28
# 64/64 - 0s - loss: 0.7367 - accuracy: 0.7573 - 256ms/epoch - 4ms/step
# Epoch 8/28
# 64/64 - 0s - loss: 0.7204 - accuracy: 0.7565 - 256ms/epoch - 4ms/step
# Epoch 9/28
# 64/64 - 0s - loss: 0.7083 - accuracy: 0.7646 - 257ms/epoch - 4ms/step
# Epoch 10/28
# 64/64 - 0s - loss: 0.6886 - accuracy: 0.7666 - 257ms/epoch - 4ms/step
# Epoch 11/28
# 64/64 - 0s - loss: 0.6905 - accuracy: 0.7668 - 258ms/epoch - 4ms/step
# Epoch 12/28
# 64/64 - 0s - loss: 0.6690 - accuracy: 0.7740 - 256ms/epoch - 4ms/step
# Epoch 13/28
# 64/64 - 0s - loss: 0.6696 - accuracy: 0.7739 - 258ms/epoch - 4ms/step
# Epoch 14/28
# 64/64 - 0s - loss: 0.6581 - accuracy: 0.7782 - 254ms/epoch - 4ms/step
# Epoch 15/28
# 64/64 - 0s - loss: 0.6547 - accuracy: 0.7807 - 258ms/epoch - 4ms/step
# Epoch 16/28
# 64/64 - 0s - loss: 0.6459 - accuracy: 0.7785 - 262ms/epoch - 4ms/step
# Epoch 17/28
# 64/64 - 0s - loss: 0.6403 - accuracy: 0.7814 - 260ms/epoch - 4ms/step
# Epoch 18/28
# 64/64 - 0s - loss: 0.6369 - accuracy: 0.7844 - 257ms/epoch - 4ms/step
# Epoch 19/28
# 64/64 - 0s - loss: 0.6348 - accuracy: 0.7820 - 258ms/epoch - 4ms/step
# Epoch 20/28
# 64/64 - 0s - loss: 0.6258 - accuracy: 0.7816 - 258ms/epoch - 4ms/step
# Epoch 21/28
# 64/64 - 0s - loss: 0.6166 - accuracy: 0.7873 - 260ms/epoch - 4ms/step
# Epoch 22/28
# 64/64 - 0s - loss: 0.6203 - accuracy: 0.7847 - 272ms/epoch - 4ms/step
# Epoch 23/28
# 64/64 - 0s - loss: 0.6208 - accuracy: 0.7857 - 263ms/epoch - 4ms/step
# Epoch 24/28
# 64/64 - 0s - loss: 0.6163 - accuracy: 0.7852 - 257ms/epoch - 4ms/step
# Epoch 25/28
# 64/64 - 0s - loss: 0.6075 - accuracy: 0.7902 - 260ms/epoch - 4ms/step
# Epoch 26/28
# 64/64 - 0s - loss: 0.6063 - accuracy: 0.7911 - 258ms/epoch - 4ms/step
# Epoch 27/28
# 64/64 - 0s - loss: 0.6024 - accuracy: 0.7902 - 260ms/epoch - 4ms/step
# Epoch 28/28
# 64/64 - 0s - loss: 0.5997 - accuracy: 0.7921 - 256ms/epoch - 4ms/step
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/28
# 64/64 - 1s - loss: 1.3444 - accuracy: 0.6160 - 1s/epoch - 19ms/step
# Epoch 2/28
# 64/64 - 0s - loss: 1.0395 - accuracy: 0.6388 - 261ms/epoch - 4ms/step
# Epoch 3/28
# 64/64 - 0s - loss: 0.9787 - accuracy: 0.6435 - 256ms/epoch - 4ms/step
# Epoch 4/28
# 64/64 - 0s - loss: 0.8771 - accuracy: 0.6926 - 256ms/epoch - 4ms/step
# Epoch 5/28
# 64/64 - 0s - loss: 0.7994 - accuracy: 0.7237 - 255ms/epoch - 4ms/step
# Epoch 6/28
# 64/64 - 0s - loss: 0.7262 - accuracy: 0.7498 - 256ms/epoch - 4ms/step
# Epoch 7/28
# 64/64 - 0s - loss: 0.7016 - accuracy: 0.7518 - 258ms/epoch - 4ms/step
# Epoch 8/28
# 64/64 - 0s - loss: 0.6739 - accuracy: 0.7642 - 252ms/epoch - 4ms/step
# Epoch 9/28
# 64/64 - 0s - loss: 0.6682 - accuracy: 0.7644 - 254ms/epoch - 4ms/step
# Epoch 10/28
# 64/64 - 0s - loss: 0.6461 - accuracy: 0.7738 - 256ms/epoch - 4ms/step
# Epoch 11/28
# 64/64 - 0s - loss: 0.6352 - accuracy: 0.7736 - 254ms/epoch - 4ms/step
# Epoch 12/28
# 64/64 - 0s - loss: 0.6261 - accuracy: 0.7823 - 257ms/epoch - 4ms/step
# Epoch 13/28
# 64/64 - 0s - loss: 0.6170 - accuracy: 0.7817 - 254ms/epoch - 4ms/step
# Epoch 14/28
# 64/64 - 0s - loss: 0.6201 - accuracy: 0.7809 - 253ms/epoch - 4ms/step
# Epoch 15/28
# 64/64 - 0s - loss: 0.5944 - accuracy: 0.7866 - 252ms/epoch - 4ms/step
# Epoch 16/28
# 64/64 - 0s - loss: 0.5789 - accuracy: 0.7964 - 253ms/epoch - 4ms/step
# Epoch 17/28
# 64/64 - 0s - loss: 0.5839 - accuracy: 0.7974 - 266ms/epoch - 4ms/step
# Epoch 18/28
# 64/64 - 0s - loss: 0.5546 - accuracy: 0.8059 - 264ms/epoch - 4ms/step
# Epoch 19/28
# 64/64 - 0s - loss: 0.5598 - accuracy: 0.8041 - 254ms/epoch - 4ms/step
# Epoch 20/28
# 64/64 - 0s - loss: 0.5481 - accuracy: 0.8039 - 255ms/epoch - 4ms/step
# Epoch 21/28
# 64/64 - 0s - loss: 0.5564 - accuracy: 0.8081 - 256ms/epoch - 4ms/step
# Epoch 22/28
# 64/64 - 0s - loss: 0.5350 - accuracy: 0.8118 - 256ms/epoch - 4ms/step
# Epoch 23/28
# 64/64 - 0s - loss: 0.5267 - accuracy: 0.8176 - 258ms/epoch - 4ms/step
# Epoch 24/28
# 64/64 - 0s - loss: 0.5170 - accuracy: 0.8222 - 258ms/epoch - 4ms/step
# Epoch 25/28
# 64/64 - 0s - loss: 0.5185 - accuracy: 0.8196 - 261ms/epoch - 4ms/step
# Epoch 26/28
# 64/64 - 0s - loss: 0.5093 - accuracy: 0.8241 - 258ms/epoch - 4ms/step
# Epoch 27/28
# 64/64 - 0s - loss: 0.4951 - accuracy: 0.8258 - 258ms/epoch - 4ms/step
# Epoch 28/28
# 64/64 - 0s - loss: 0.5076 - accuracy: 0.8242 - 257ms/epoch - 4ms/step
# 115/115 [==============================] - 0s 1ms/step
# Epoch 1/28
# 64/64 - 1s - loss: 1.2752 - accuracy: 0.5942 - 1s/epoch - 19ms/step
# Epoch 2/28
# 64/64 - 0s - loss: 0.9741 - accuracy: 0.6695 - 258ms/epoch - 4ms/step
# Epoch 3/28
# 64/64 - 0s - loss: 0.8875 - accuracy: 0.7106 - 256ms/epoch - 4ms/step
# Epoch 4/28
# 64/64 - 0s - loss: 0.8366 - accuracy: 0.7209 - 259ms/epoch - 4ms/step
# Epoch 5/28
# 64/64 - 0s - loss: 0.7898 - accuracy: 0.7319 - 258ms/epoch - 4ms/step
# Epoch 6/28
# 64/64 - 0s - loss: 0.7583 - accuracy: 0.7399 - 258ms/epoch - 4ms/step
# Epoch 7/28
# 64/64 - 0s - loss: 0.7351 - accuracy: 0.7493 - 258ms/epoch - 4ms/step
# Epoch 8/28
# 64/64 - 0s - loss: 0.7271 - accuracy: 0.7516 - 259ms/epoch - 4ms/step
# Epoch 9/28
# 64/64 - 0s - loss: 0.6903 - accuracy: 0.7659 - 257ms/epoch - 4ms/step
# Epoch 10/28
# 64/64 - 0s - loss: 0.6830 - accuracy: 0.7687 - 257ms/epoch - 4ms/step
# Epoch 11/28
# 64/64 - 0s - loss: 0.6736 - accuracy: 0.7697 - 257ms/epoch - 4ms/step
# Epoch 12/28
# 64/64 - 0s - loss: 0.6632 - accuracy: 0.7763 - 256ms/epoch - 4ms/step
# Epoch 13/28
# 64/64 - 0s - loss: 0.6575 - accuracy: 0.7759 - 257ms/epoch - 4ms/step
# Epoch 14/28
# 64/64 - 0s - loss: 0.6451 - accuracy: 0.7800 - 258ms/epoch - 4ms/step
# Epoch 15/28
# 64/64 - 0s - loss: 0.6395 - accuracy: 0.7817 - 260ms/epoch - 4ms/step
# Epoch 16/28
# 64/64 - 0s - loss: 0.6467 - accuracy: 0.7789 - 263ms/epoch - 4ms/step
# Epoch 17/28
# 64/64 - 0s - loss: 0.6347 - accuracy: 0.7823 - 260ms/epoch - 4ms/step
# Epoch 18/28
# 64/64 - 0s - loss: 0.6279 - accuracy: 0.7833 - 261ms/epoch - 4ms/step
# Epoch 19/28
# 64/64 - 0s - loss: 0.6272 - accuracy: 0.7836 - 253ms/epoch - 4ms/step
# Epoch 20/28
# 64/64 - 0s - loss: 0.6225 - accuracy: 0.7844 - 254ms/epoch - 4ms/step
# Epoch 21/28
# 64/64 - 0s - loss: 0.6178 - accuracy: 0.7891 - 257ms/epoch - 4ms/step
# Epoch 22/28
# 64/64 - 0s - loss: 0.6119 - accuracy: 0.7874 - 254ms/epoch - 4ms/step
# Epoch 23/28
# 64/64 - 0s - loss: 0.6136 - accuracy: 0.7838 - 254ms/epoch - 4ms/step
# Epoch 24/28
# 64/64 - 0s - loss: 0.6072 - accuracy: 0.7898 - 257ms/epoch - 4ms/step
# Epoch 25/28
# 64/64 - 0s - loss: 0.5952 - accuracy: 0.7906 - 253ms/epoch - 4ms/step
# Epoch 26/28
# 64/64 - 0s - loss: 0.6021 - accuracy: 0.7910 - 253ms/epoch - 4ms/step
# Epoch 27/28
# 64/64 - 0s - loss: 0.5935 - accuracy: 0.7921 - 273ms/epoch - 4ms/step
# Epoch 28/28
# 64/64 - 0s - loss: 0.5908 - accuracy: 0.7943 - 253ms/epoch - 4ms/step
# 115/115 [==============================] - 0s 2ms/step
# Epoch 1/28
# 64/64 - 1s - loss: 1.2243 - accuracy: 0.6078 - 1s/epoch - 19ms/step
# Epoch 2/28
# 64/64 - 0s - loss: 0.9920 - accuracy: 0.6653 - 253ms/epoch - 4ms/step
# Epoch 3/28
# 64/64 - 0s - loss: 0.8749 - accuracy: 0.7026 - 258ms/epoch - 4ms/step
# Epoch 4/28
# 64/64 - 0s - loss: 0.8057 - accuracy: 0.7287 - 257ms/epoch - 4ms/step
# Epoch 5/28
# 64/64 - 0s - loss: 0.7674 - accuracy: 0.7390 - 257ms/epoch - 4ms/step
# Epoch 6/28
# 64/64 - 0s - loss: 0.7402 - accuracy: 0.7490 - 253ms/epoch - 4ms/step
# Epoch 7/28
# 64/64 - 0s - loss: 0.7150 - accuracy: 0.7551 - 256ms/epoch - 4ms/step
# Epoch 8/28
# 64/64 - 0s - loss: 0.7066 - accuracy: 0.7597 - 257ms/epoch - 4ms/step
# Epoch 9/28
# 64/64 - 0s - loss: 0.6948 - accuracy: 0.7616 - 262ms/epoch - 4ms/step
# Epoch 10/28
# 64/64 - 0s - loss: 0.6848 - accuracy: 0.7629 - 258ms/epoch - 4ms/step
# Epoch 11/28
# 64/64 - 0s - loss: 0.6744 - accuracy: 0.7662 - 256ms/epoch - 4ms/step
# Epoch 12/28
# 64/64 - 0s - loss: 0.6690 - accuracy: 0.7694 - 261ms/epoch - 4ms/step
# Epoch 13/28
# 64/64 - 0s - loss: 0.6613 - accuracy: 0.7711 - 267ms/epoch - 4ms/step
# Epoch 14/28
# 64/64 - 0s - loss: 0.6508 - accuracy: 0.7744 - 260ms/epoch - 4ms/step
# Epoch 15/28
# 64/64 - 0s - loss: 0.6502 - accuracy: 0.7717 - 263ms/epoch - 4ms/step
# Epoch 16/28
# 64/64 - 0s - loss: 0.6455 - accuracy: 0.7749 - 264ms/epoch - 4ms/step
# Epoch 17/28
# 64/64 - 0s - loss: 0.6215 - accuracy: 0.7834 - 261ms/epoch - 4ms/step
# Epoch 18/28
# 64/64 - 0s - loss: 0.6362 - accuracy: 0.7770 - 256ms/epoch - 4ms/step
# Epoch 19/28
# 64/64 - 0s - loss: 0.6281 - accuracy: 0.7783 - 253ms/epoch - 4ms/step
# Epoch 20/28
# 64/64 - 0s - loss: 0.6189 - accuracy: 0.7815 - 257ms/epoch - 4ms/step
# Epoch 21/28
# 64/64 - 0s - loss: 0.6240 - accuracy: 0.7827 - 258ms/epoch - 4ms/step
# Epoch 22/28
# 64/64 - 0s - loss: 0.5975 - accuracy: 0.7899 - 257ms/epoch - 4ms/step
# Epoch 23/28
# 64/64 - 0s - loss: 0.6028 - accuracy: 0.7867 - 253ms/epoch - 4ms/step
# Epoch 24/28
# 64/64 - 0s - loss: 0.6005 - accuracy: 0.7898 - 253ms/epoch - 4ms/step
# Epoch 25/28
# 64/64 - 0s - loss: 0.6014 - accuracy: 0.7856 - 254ms/epoch - 4ms/step
# Epoch 26/28
# 64/64 - 0s - loss: 0.5867 - accuracy: 0.7898 - 257ms/epoch - 4ms/step
# Epoch 27/28
# 64/64 - 0s - loss: 0.5836 - accuracy: 0.7908 - 256ms/epoch - 4ms/step
# Epoch 28/28
# 64/64 - 0s - loss: 0.5795 - accuracy: 0.7968 - 253ms/epoch - 4ms/step
# 115/115 [==============================] - 0s 1ms/step
# | 19        | 0.7672    | 8.061     | 231.8     | 0.2172    | 0.1102    | 28.33     | 2.195     | 1.198     | 2.732     | 0.5165    | 10.75     | 0.7689    | 3.857     |
# =========================================================================================================================================================================
# Search took 36.332423734664914 minutes

# %%
optimum = nn_opt.max['params']
learning_rate = optimum['learning_rate']
activationL = ['relu', 'sigmoid', 'softplus', 'softsign', 'tanh', 'selu',
               'elu', 'exponential', LeakyReLU,'relu']
optimum['activation'] = activationL[round(optimum['activation'])]
optimum['batch_size'] = round(optimum['batch_size'])
optimum['epochs'] = round(optimum['epochs'])
optimum['layers1'] = round(optimum['layers1'])
optimum['layers2'] = round(optimum['layers2'])
optimum['neurons'] = round(optimum['neurons'])
optimizerL = ['Adam', 'SGD', 'RMSprop', 'Adadelta', 'Adagrad', 'Adamax', 'Nadam', 'Ftrl','Adam']
optimizerD= {'Adam':Adam(lr=learning_rate), 'SGD':SGD(lr=learning_rate),
             'RMSprop':RMSprop(lr=learning_rate), 'Adadelta':Adadelta(lr=learning_rate),
             'Adagrad':Adagrad(lr=learning_rate), 'Adamax':Adamax(lr=learning_rate),
             'Nadam':Nadam(lr=learning_rate), 'Ftrl':Ftrl(lr=learning_rate)}
optimum['optimizer'] = optimizerD[optimizerL[round(optimum['optimizer'])]]
optimum
# Out:
# {'activation': 'softsign',
#  'batch_size': 298,
#  'dropout': 0.7296061783380641,
#  'dropout_rate': 0.19126724140656393,
#  'epochs': 47,
#  'kernel': 1.9444298503238986,
#  'layers1': 1,
#  'layers2': 2,
#  'learning_rate': 0.7631771981307285,
#  'neurons': 32,
#  'normalization': 0.770967179954561,
#  'optimizer': <keras.optimizers.optimizer_v2.adadelta.Adadelta at 0x7fa1fa0510a0>}

# %%
####Need to add learning rate to the optimizer type??
epochs = 91
batch_size = 460
#n_hidden = 32

timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = 15 #_count_classes(y_train)
layers1 = 1
layers2 = 2
activation = 'softsign'
kernel = 1
neurons = 61
normalization = 0.771
dropout = 0.7296
dropout_rate = 0.1912
optimizer = 'Adadelta'

model = Sequential()
model.add(Conv1D(neurons, kernel_size=kernel, activation=activation, input_shape=(timesteps, input_dim)))
if normalization > 0.5:
    model.add(BatchNormalization())
for i in range(layers1):
    model.add(Dense(neurons, activation=activation))
if dropout > 0.5:
    model.add(Dropout(dropout_rate, seed=123))
for i in range(layers2):
    model.add(Dense(neurons, activation=activation))
model.add(MaxPooling1D())
model.add(Flatten())
model.add(Dense(n_classes, activation='softmax')) #softmax sigmoid
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy']) #binary_crossentropy

# %%
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=2)
# Out:
# Epoch 1/91
# 40/40 - 2s - loss: 2.7518 - accuracy: 0.0136 - 2s/epoch - 46ms/step
# Epoch 2/91
# 40/40 - 1s - loss: 2.7417 - accuracy: 0.0170 - 847ms/epoch - 21ms/step
# Epoch 3/91
# 40/40 - 1s - loss: 2.7295 - accuracy: 0.0208 - 843ms/epoch - 21ms/step
# Epoch 4/91
# 40/40 - 1s - loss: 2.7174 - accuracy: 0.0248 - 847ms/epoch - 21ms/step
# Epoch 5/91
# 40/40 - 1s - loss: 2.7058 - accuracy: 0.0301 - 845ms/epoch - 21ms/step
# Epoch 6/91
# 40/40 - 1s - loss: 2.6928 - accuracy: 0.0367 - 838ms/epoch - 21ms/step
# Epoch 7/91
# 40/40 - 1s - loss: 2.6809 - accuracy: 0.0437 - 855ms/epoch - 21ms/step
# Epoch 8/91
# 40/40 - 1s - loss: 2.6680 - accuracy: 0.0546 - 835ms/epoch - 21ms/step
# Epoch 9/91
# 40/40 - 1s - loss: 2.6539 - accuracy: 0.0674 - 837ms/epoch - 21ms/step
# Epoch 10/91
# 40/40 - 1s - loss: 2.6397 - accuracy: 0.0779 - 839ms/epoch - 21ms/step
# Epoch 11/91
# 40/40 - 1s - loss: 2.6256 - accuracy: 0.0970 - 840ms/epoch - 21ms/step
# Epoch 12/91
# 40/40 - 1s - loss: 2.6114 - accuracy: 0.1114 - 854ms/epoch - 21ms/step
# Epoch 13/91
# 40/40 - 1s - loss: 2.5987 - accuracy: 0.1302 - 850ms/epoch - 21ms/step
# Epoch 14/91
# 40/40 - 1s - loss: 2.5827 - accuracy: 0.1481 - 844ms/epoch - 21ms/step
# Epoch 15/91
# 40/40 - 1s - loss: 2.5692 - accuracy: 0.1682 - 848ms/epoch - 21ms/step
# Epoch 16/91
# 40/40 - 1s - loss: 2.5535 - accuracy: 0.1888 - 847ms/epoch - 21ms/step
# Epoch 17/91
# 40/40 - 1s - loss: 2.5397 - accuracy: 0.2099 - 842ms/epoch - 21ms/step
# Epoch 18/91
# 40/40 - 1s - loss: 2.5234 - accuracy: 0.2298 - 835ms/epoch - 21ms/step
# Epoch 19/91
# 40/40 - 1s - loss: 2.5076 - accuracy: 0.2501 - 850ms/epoch - 21ms/step
# Epoch 20/91
# 40/40 - 1s - loss: 2.4925 - accuracy: 0.2745 - 881ms/epoch - 22ms/step
# Epoch 21/91
# 40/40 - 1s - loss: 2.4766 - accuracy: 0.2892 - 860ms/epoch - 21ms/step
# Epoch 22/91
# 40/40 - 1s - loss: 2.4596 - accuracy: 0.3125 - 842ms/epoch - 21ms/step
# Epoch 23/91
# 40/40 - 1s - loss: 2.4435 - accuracy: 0.3350 - 849ms/epoch - 21ms/step
# Epoch 24/91
# 40/40 - 1s - loss: 2.4270 - accuracy: 0.3496 - 837ms/epoch - 21ms/step
# Epoch 25/91
# 40/40 - 1s - loss: 2.4103 - accuracy: 0.3667 - 849ms/epoch - 21ms/step
# Epoch 26/91
# 40/40 - 1s - loss: 2.3939 - accuracy: 0.3798 - 836ms/epoch - 21ms/step
# Epoch 27/91
# 40/40 - 1s - loss: 2.3762 - accuracy: 0.4015 - 834ms/epoch - 21ms/step
# Epoch 28/91
# 40/40 - 1s - loss: 2.3596 - accuracy: 0.4126 - 830ms/epoch - 21ms/step
# Epoch 29/91
# 40/40 - 1s - loss: 2.3435 - accuracy: 0.4284 - 833ms/epoch - 21ms/step
# Epoch 30/91
# 40/40 - 1s - loss: 2.3276 - accuracy: 0.4433 - 836ms/epoch - 21ms/step
# Epoch 31/91
# 40/40 - 1s - loss: 2.3089 - accuracy: 0.4525 - 837ms/epoch - 21ms/step
# Epoch 32/91
# 40/40 - 1s - loss: 2.2917 - accuracy: 0.4636 - 831ms/epoch - 21ms/step
# Epoch 33/91
# 40/40 - 1s - loss: 2.2734 - accuracy: 0.4739 - 828ms/epoch - 21ms/step
# Epoch 34/91
# 40/40 - 1s - loss: 2.2560 - accuracy: 0.4858 - 831ms/epoch - 21ms/step
# Epoch 35/91
# 40/40 - 1s - loss: 2.2401 - accuracy: 0.4989 - 837ms/epoch - 21ms/step
# Epoch 36/91
# 40/40 - 1s - loss: 2.2210 - accuracy: 0.5117 - 862ms/epoch - 22ms/step
# Epoch 37/91
# 40/40 - 1s - loss: 2.2037 - accuracy: 0.5232 - 840ms/epoch - 21ms/step
# Epoch 38/91
# 40/40 - 1s - loss: 2.1864 - accuracy: 0.5314 - 840ms/epoch - 21ms/step
# Epoch 39/91
# 40/40 - 1s - loss: 2.1671 - accuracy: 0.5406 - 831ms/epoch - 21ms/step
# Epoch 40/91
# 40/40 - 1s - loss: 2.1510 - accuracy: 0.5502 - 838ms/epoch - 21ms/step
# Epoch 41/91
# 40/40 - 1s - loss: 2.1331 - accuracy: 0.5598 - 850ms/epoch - 21ms/step
# Epoch 42/91
# 40/40 - 1s - loss: 2.1162 - accuracy: 0.5650 - 847ms/epoch - 21ms/step
# Epoch 43/91
# 40/40 - 1s - loss: 2.0973 - accuracy: 0.5738 - 840ms/epoch - 21ms/step
# Epoch 44/91
# 40/40 - 1s - loss: 2.0793 - accuracy: 0.5801 - 839ms/epoch - 21ms/step
# Epoch 45/91
# 40/40 - 1s - loss: 2.0604 - accuracy: 0.5884 - 845ms/epoch - 21ms/step
# Epoch 46/91
# 40/40 - 1s - loss: 2.0428 - accuracy: 0.5947 - 845ms/epoch - 21ms/step
# Epoch 47/91
# 40/40 - 1s - loss: 2.0254 - accuracy: 0.5981 - 841ms/epoch - 21ms/step
# Epoch 48/91
# 40/40 - 1s - loss: 2.0072 - accuracy: 0.6051 - 848ms/epoch - 21ms/step
# Epoch 49/91
# 40/40 - 1s - loss: 1.9894 - accuracy: 0.6089 - 838ms/epoch - 21ms/step
# Epoch 50/91
# 40/40 - 1s - loss: 1.9718 - accuracy: 0.6143 - 835ms/epoch - 21ms/step
# Epoch 51/91
# 40/40 - 1s - loss: 1.9549 - accuracy: 0.6167 - 842ms/epoch - 21ms/step
# Epoch 52/91
# 40/40 - 1s - loss: 1.9363 - accuracy: 0.6208 - 850ms/epoch - 21ms/step
# Epoch 53/91
# 40/40 - 1s - loss: 1.9193 - accuracy: 0.6245 - 841ms/epoch - 21ms/step
# Epoch 54/91
# 40/40 - 1s - loss: 1.9011 - accuracy: 0.6266 - 839ms/epoch - 21ms/step
# Epoch 55/91
# 40/40 - 1s - loss: 1.8843 - accuracy: 0.6292 - 844ms/epoch - 21ms/step
# Epoch 56/91
# 40/40 - 1s - loss: 1.8666 - accuracy: 0.6313 - 852ms/epoch - 21ms/step
# Epoch 57/91
# 40/40 - 1s - loss: 1.8510 - accuracy: 0.6340 - 839ms/epoch - 21ms/step
# Epoch 58/91
# 40/40 - 1s - loss: 1.8337 - accuracy: 0.6333 - 838ms/epoch - 21ms/step
# Epoch 59/91
# 40/40 - 1s - loss: 1.8161 - accuracy: 0.6359 - 833ms/epoch - 21ms/step
# Epoch 60/91
# 40/40 - 1s - loss: 1.7998 - accuracy: 0.6368 - 830ms/epoch - 21ms/step
# Epoch 61/91
# 40/40 - 1s - loss: 1.7845 - accuracy: 0.6381 - 838ms/epoch - 21ms/step
# Epoch 62/91
# 40/40 - 1s - loss: 1.7667 - accuracy: 0.6381 - 841ms/epoch - 21ms/step
# Epoch 63/91
# 40/40 - 1s - loss: 1.7522 - accuracy: 0.6387 - 843ms/epoch - 21ms/step
# Epoch 64/91
# 40/40 - 1s - loss: 1.7367 - accuracy: 0.6387 - 849ms/epoch - 21ms/step
# Epoch 65/91
# 40/40 - 1s - loss: 1.7213 - accuracy: 0.6399 - 847ms/epoch - 21ms/step
# Epoch 66/91
# 40/40 - 1s - loss: 1.7050 - accuracy: 0.6402 - 844ms/epoch - 21ms/step
# Epoch 67/91
# 40/40 - 1s - loss: 1.6889 - accuracy: 0.6411 - 845ms/epoch - 21ms/step
# Epoch 68/91
# 40/40 - 1s - loss: 1.6747 - accuracy: 0.6412 - 845ms/epoch - 21ms/step
# Epoch 69/91
# 40/40 - 1s - loss: 1.6594 - accuracy: 0.6413 - 841ms/epoch - 21ms/step
# Epoch 70/91
# 40/40 - 1s - loss: 1.6440 - accuracy: 0.6412 - 843ms/epoch - 21ms/step
# Epoch 71/91
# 40/40 - 1s - loss: 1.6305 - accuracy: 0.6416 - 848ms/epoch - 21ms/step
# Epoch 72/91
# 40/40 - 1s - loss: 1.6160 - accuracy: 0.6418 - 853ms/epoch - 21ms/step
# Epoch 73/91
# 40/40 - 1s - loss: 1.6041 - accuracy: 0.6420 - 843ms/epoch - 21ms/step
# Epoch 74/91
# 40/40 - 1s - loss: 1.5900 - accuracy: 0.6424 - 842ms/epoch - 21ms/step
# Epoch 75/91
# 40/40 - 1s - loss: 1.5765 - accuracy: 0.6424 - 840ms/epoch - 21ms/step
# Epoch 76/91
# 40/40 - 1s - loss: 1.5622 - accuracy: 0.6424 - 850ms/epoch - 21ms/step
# Epoch 77/91
# 40/40 - 1s - loss: 1.5495 - accuracy: 0.6426 - 839ms/epoch - 21ms/step
# Epoch 78/91
# 40/40 - 1s - loss: 1.5386 - accuracy: 0.6427 - 835ms/epoch - 21ms/step
# Epoch 79/91
# 40/40 - 1s - loss: 1.5247 - accuracy: 0.6428 - 838ms/epoch - 21ms/step
# Epoch 80/91
# 40/40 - 1s - loss: 1.5143 - accuracy: 0.6428 - 838ms/epoch - 21ms/step
# Epoch 81/91
# 40/40 - 1s - loss: 1.5025 - accuracy: 0.6425 - 832ms/epoch - 21ms/step
# Epoch 82/91
# 40/40 - 1s - loss: 1.4902 - accuracy: 0.6424 - 838ms/epoch - 21ms/step
# Epoch 83/91
# 40/40 - 1s - loss: 1.4779 - accuracy: 0.6425 - 837ms/epoch - 21ms/step
# Epoch 84/91
# 40/40 - 1s - loss: 1.4692 - accuracy: 0.6429 - 841ms/epoch - 21ms/step
# Epoch 85/91
# 40/40 - 1s - loss: 1.4568 - accuracy: 0.6426 - 837ms/epoch - 21ms/step
# Epoch 86/91
# 40/40 - 1s - loss: 1.4474 - accuracy: 0.6428 - 836ms/epoch - 21ms/step
# Epoch 87/91
# 40/40 - 1s - loss: 1.4352 - accuracy: 0.6428 - 838ms/epoch - 21ms/step
# Epoch 88/91
# 40/40 - 1s - loss: 1.4265 - accuracy: 0.6429 - 837ms/epoch - 21ms/step
# Epoch 89/91
# 40/40 - 1s - loss: 1.4181 - accuracy: 0.6428 - 836ms/epoch - 21ms/step
# Epoch 90/91
# 40/40 - 1s - loss: 1.4087 - accuracy: 0.6428 - 844ms/epoch - 21ms/step
# Epoch 91/91
# 40/40 - 1s - loss: 1.3995 - accuracy: 0.6428 - 853ms/epoch - 21ms/step

# %%
predictions = {
0: 'BASEL',
1: 'BELGRADE',
2: 'BUDAPEST',
3: 'DEBILT',
4: 'DUSSELDORF',
5: 'HEATHROW',
6: 'KASSEL',
7: 'LJUBLJANA',
8: 'MAASTRICHT',
9: 'MADRID',
10: 'MUNCHENB',
11: 'OSLO',
12: 'SONNBLICK',
13: 'STOCKHOLM',
14: 'VALENTIA'
}

# %%
def confusion_matrix(y_true, y_pred, predictions):
    # Check if y_true and y_pred are one-hot encoded or already class indices
    if y_true.ndim == 1:
        y_true_labels = y_true
    else:
        y_true_labels = np.argmax(y_true, axis=1)

    if y_pred.ndim == 1:
        y_pred_labels = y_pred
    else:
        y_pred_labels = np.argmax(y_pred, axis=1)
        
    # Map numeric labels to activity names
    y_true_series = pd.Series([predictions[y] for y in y_true_labels])
    y_pred_series = pd.Series([predictions[y] for y in y_pred_labels])

    return pd.crosstab(y_true_series, y_pred_series, rownames=['True'], colnames=['Pred'])

# %%
pred = model.predict(X_test)
pred.shape
# Out:
# 144/144 [==============================] - 0s 2ms/step
# (4590, 15)

# %%
y_test.shape
# Out:
# (4590,)

# %%
# Generate the model's predictions
pred = model.predict(X_test)

# Convert the predictions from probabilities to class indices
pred_classes = np.argmax(pred, axis=1)

# Evaluate
print(confusion_matrix(y_test, pred_classes, predictions))
# Out:
# 144/144 [==============================] - 0s 2ms/step
# Pred        BASEL
# True
# BASEL        2964
# BELGRADE      879
# BUDAPEST      169
# DEBILT         70
# DUSSELDORF     25
# HEATHROW       74
# KASSEL          5
# LJUBLJANA      45
# MAASTRICHT      3
# MADRID        341
# MUNCHENB        5
# OSLO            4
# STOCKHOLM       4
# VALENTIA        2
