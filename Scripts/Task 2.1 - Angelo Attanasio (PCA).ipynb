# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from matplotlib.pyplot import figure
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# Create a path
path = r'C:\Users\Asus-Pc\Desktop\CareerFoundry\Machine Learning with Python'

# %%
# Import reduced dataframe
df_reduced =  pd.read_csv (os.path.join(path,'PCA_1987.csv'), index_col = False)
df_reduced
# Out:
#        Unnamed: 0      PCA1      PCA2      PCA3      PCA4      PCA5      PCA6  \
# 0               0  6.592609  3.579805 -2.501814  3.464235 -1.493313  2.072482
# 1               1  6.927035  3.750666 -2.309615  0.954381 -1.248872  0.003192
# 2               2  7.224329  2.623387 -2.905954 -2.194737 -2.026932 -0.384548
# 3               3  7.684972  0.175528 -4.253392 -1.526586 -1.039717  1.067500
# 4               4  7.430865  0.408172 -3.526692 -0.288853  0.498547  2.019863
# ...           ...       ...       ...       ...       ...       ...       ...
# 22945       22945 -3.862950 -0.084906 -3.400667  2.033683 -1.480219  0.707765
# 22946       22946 -4.130789  0.533993 -3.304263  1.367552 -1.650774  0.945200
# 22947       22947 -4.314672  0.525764 -3.035404  0.725271 -0.931612 -0.311630
# 22948       22948 -3.040648 -0.036320 -2.568006  0.979070 -1.653340 -0.783425
# 22949       22949 -1.575026  1.273140 -2.128848  1.002554 -1.698083 -1.366842
#
# ...

# %%
# Import weather dataset
df_weather = pd.read_csv(os.path.join(path, 'Weather_dataset.csv'), index_col = False)
df_weather
# Out:
#            DATE  BASEL_pleasant_weather  BELGRADE_pleasant_weather  \
# 0      19600101                       0                          0
# 1      19600102                       0                          0
# 2      19600103                       0                          0
# 3      19600104                       0                          0
# 4      19600105                       0                          0
# ...         ...                     ...                        ...
# 22945  20221027                       0                          0
# 22946  20221028                       0                          0
# 22947  20221029                       0                          0
# 22948  20221030                       0                          0
# 22949  20221031                       0                          0
#
#        BUDAPEST_pleasant_weather  DEBILT_pleasant_weather  \
# 0                              0                        0
# ...

# %%
#Dendogram for PCA - single method

distance_single = linkage(df_reduced.loc[:365,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6', 
'PCA7',
'PCA8', 
'PCA9',
'PCA10',
'PCA11']],method="single")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("PCA Single Method",fontsize=18)
plt.show()

# %%
#Dendogram for PCA - complete method

distance_single = linkage(df_reduced.loc[:365,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6', 
'PCA7',
'PCA8', 
'PCA9',
'PCA10',
'PCA11']],method="complete")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("PCA Complete Method",fontsize=18)
plt.show()

# %%
#Dendogram for PCA - complete method

distance_single = linkage(df_reduced.loc[:365,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6', 
'PCA7',
'PCA8', 
'PCA9',
'PCA10',
'PCA11']],method="average")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("PCA Average Method",fontsize=18)
plt.show()

# %%
#Dendogram for PCA - ward method

distance_single = linkage(df_reduced.loc[:365,
['PCA1',
'PCA2',
'PCA3',
'PCA4',
'PCA5',
'PCA6', 
'PCA7',
'PCA8', 
'PCA9',
'PCA10',
'PCA11']],method="ward")
plt.figure(figsize=(18,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle("PCA Ward Method",fontsize=18)
plt.show()
